# %% [markdown]
# ## Housing

# %% [markdown]
# ### Fig.27-28 Residential Permit Info
# ### Not from Census
# + leaving these as is

# %% [markdown]
# ### Fig.29 Age of Housing Stock Graphic
# make both stacked horizontal bar and bar chart with % by decade

# %% [markdown]
# ### Fig.30 Median Year Residential Stucture Built Graphic...
# Change to geography of interest only

# %% [markdown]
# ### Fig.31 Residential Building Type Mix Graphic
# county plus all places for either county or place plan. Single family vs all multi family bar composition charts, 2020

# %% [markdown]
# ### Fig.32 Residential Building Permit by Type Table
# leave as is

# %% [markdown]
# ### Fig.33 Percent Change in Housing Units by Type, 2000 - 2019...
# + boats + mobile home, 1 unit
# + 2 to 4
# + 5 to 49
# + 50 or more
#
# ##### Separate figure for 1 units
# + 1 unit attached is a town home, 1 unit detached is a house

# %% [markdown]
# ### Fig.34 + 35 Ownership
# + time trend GOI
# + compare nation, state, region, county, uninc/inc., place if it's a place
# + checking into age and race

# %% [markdown]
# ### Fig.36 Occupancy
# Keep it the same maybe --- can we make this more interesting?

# %% [markdown]
# ### Fig.37 Tenure and Mortgage Status
# Tenure over time GOI
# Point in time mortgage status GOI

# %% [markdown]
# ## Affordability

# %% [markdown]
# ### Figure X.s
# + GOI median gross rent over time
# + Change in mgr over last 20 years comparative geos
# + add in migration component
# + take out adjusted for inflation
# + echo the same for median selected owner costs
#
# + GOI home value over time
# + GOI change over last 20 years comparative geos
# + Zillow GOI over time (county for place)
# + Change in Home Values '96 - '21 for state, region, county of interest, counties that touch
# Cost Burden 3 line graphs separtae
# + GOI and comparative geos total cb over time
# + GOI just renter + extreme
# + GOI just owner + extreme

# %% [markdown]
# ### Figure X.s  Housing and Transportation Costs Compared to Median Household Income
# + Same thing for the housing costs - select counties that touch
# + Change the line to a target marker and gradient down to show the difference
# + add housing and transportation and take out that being two different numbers
