# %% [markdown]
# ###### Imports and Settings

# %%
import pandas as pd
import numpy as np
import requests
#import io
import pickle
import dataframe_image as dfi
from collections import deque
from functools import reduce
import matplotlib.pyplot as plt
#pd.options.display.float_format = '{:,.0f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
def prettypercentchange(x, y):
    return round((x - y)*100/y, 1).astype(str)+'%'
def mathpercentchange(x, y):
    return round((x - y)/y, 1)

# %%
data = pd.read_csv('../../data/gallatinfigures.csv')

# %%
data.head(10)
# Out:
#              NAME  Year   Population  Male Under 5  Female Under 5  Male 5 to 9  Female 5 to 9  Male 10 to 14  Female 10 to 14  Male 15 to 17  \
# 0   Sumner County  2000     130449.0        4567.0          4266.0       4862.0         4574.0         5077.0           4773.0         3242.0
# 1        Gallatin  2000      23230.0         844.0           856.0        818.0          748.0          818.0            797.0          517.0
# 2  Goodlettsville  2000      13780.0         466.0           452.0        454.0          470.0          491.0            410.0          273.0
# 3  Hendersonville  2000      40620.0        1401.0          1266.0       1501.0         1378.0         1576.0           1453.0         1005.0
# 4    Millersville  2000       5308.0         254.0           228.0        237.0          203.0          207.0            160.0           96.0
# ...

# %% [markdown]
# # Population
# ## Total Population 2000 to 2020

# %%
fig, ax = plt.subplots(figsize = (10, 5)) #creating figure containing a single axis
#fig, axs = plt.subplots(2, 2) #figure w/ 2x2 grid of axes
ax.plot(x, #x
        y, #y
        marker = 'o', #marker
        color = '#00263E', #marker color
        alpha = 0.5, #transparency
       
       )
ax.set(title = title, 
      xlabel = xlabel, 
      ylabel = ylabel)
ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f')) #set the decimal tolerance for x axis
ax.grid(linestyle='-', linewidth='0.5', color='#6DB0C7') #set only major grid
#below is setting both a major and a minor grid
# # Customize the major grid
# ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# # Turn on the minor TICKS, which are required for the minor GRID
# ax.minorticks_on()
# # Customize the minor grid
# ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

#set limit on population because it looks weird
ax.set_ylim(20000, 45500)
# # Don't allow the axis to be on top of your data
# ax.set_axisbelow(True)
#color of background
ax.set_facecolor('#F4F8F9')
# for index in range(len(x)):
#   ax.text(x[index], y[index], y[index], size=12)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23104/2467805339.py in <module>
#      11       xlabel = xlabel,
#      12       ylabel = ylabel)
# ---> 13 ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f')) #set the decimal tolerance for x axis
#      14 ax.grid(linestyle='-', linewidth='0.5', color='#6DB0C7') #set only major grid
#      15 #below is setting both a major and a minor grid
#
# NameError: name 'FormatStrFormatter' is not defined

# %%
gallonly = data.loc[data['NAME'] == 'Gallatin']

# %%
plt.style.use('seaborn-pastel')

from matplotlib.ticker import StrMethodFormatter
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}')) # No decimal places
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}')) # 2 decimal places

# %%
SMALL_SIZE = 10
MEDIUM_SIZE = 12
BIGGER_SIZE = 18
BIGGEST_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('axes', titlesize=BIGGEST_SIZE)  # fontsize of the figure title

from matplotlib import rcParams
rcParams['font.family'] = 'calibri'
import matplotlib as mpl

COLOR = '#00263E'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['axes.labelpad'] = 15
mpl.rcParams['axes.titlepad'] = 20
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR

# %%
#this is using _repr_html_ method to create an html representation of our table
styles = [
    #TH: Tabular Header
    dict(selector = 'th', props = [('background', '#7B7E85'), 
                                   #('line-height','100px'),
                                   ('color', 'white'),('word-wrap','break-word'),
                                   ('text-align', 'center'),('font-family', 'din 2014'),('max-width','100px'),
                                   ("border", "1px solid #eee"),("text-transform", "uppercase")
                                  ]),
#     #Table: Table
#     dict(selector="table", props=[("font-family" , 'din 2014'),('background', 'red'),('width','3000px'),("border-collapse" , "collapse")]),
    #TD: Cells/Tabular Data
    dict(selector = 'td', props = [('font-family', 'din 2014'),('text-align', 'left'),('word-wrap','break-word'),
                                   ("border", "1px solid #eee")]),
    dict(selector = 'tr:nth-of-type(odd)', props = [('background', '#F2ECEB')]), 
    dict(selector = 'tr:nth-of-type(even)', props = [('background', 'white')]),
    dict(selector = 'tr:hover', props = [('background-color', 'teal')]),
    dict(selector="caption", props=[("text-align", "center"),("color", "white"),("font-size", "200%"),("font-family" , 'din 2014'),
                                    ("margin" , "0px auto"),("border", "1px solid #eee"),('background', '#6DB0C7')])
    
]

# %%
# # another way for fonts
# font1 = {'family':'serif','color':'blue','size':20}
# font2 = {'family':'serif','color':'darkred','size':15}

# plt.title("Sports Watch Data", fontdict = font1)
# plt.xlabel("Average Pulse", fontdict = font2)
# plt.ylabel("Calorie Burnage", fontdict = font2)

# %%
x = gallonly['Year']
y = gallonly['Population']
title = 'Population of Gallatin\n 2000 - 2020'
xlabel = 'Year'
ylabel = 'Population'
ylimlow = 20000
ylimhigh = 45500
txt = 'Citation: 2000, 2010, and 2020 Decennial Census'

# %%
data['Year'] = data['Year'].astype(float)

# %%
fig, ax = plt.subplots(figsize = (10, 5))
ax.plot(x, y,
        marker = 'o', #marker
        color = '#00263E', #marker color
        alpha = 0.5, #transparency
        linewidth = 2
       )
ax.set(title = title, 
      xlabel = xlabel, 
      ylabel = ylabel)
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.0f')) #set the decimal tolerance for x axis
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
ax.grid(linestyle='-', linewidth='0.5', color='#6DB0C7') #set only major grid
ax.set_ylim(ylimlow, ylimhigh)
ax.tick_params(axis='both', which='major', pad=5)
ax.set_facecolor('#F4F8F9')
#citation label
fig.text(.4, .0009, txt, ha='right')
#try labels
for j, k in zip(x, y):
    label = "{:,.0f}".format(k)
    plt.annotate(label, 
                (j, k), 
                textcoords = 'offset points', 
                xytext = (0, -20), 
                ha = 'center')
#ax.tight_layout()
#plt.savefig('formattest.png')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23104/3465605992.py in <module>
#       9       xlabel = xlabel,
#      10       ylabel = ylabel)
# ---> 11 ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f')) #set the decimal tolerance for x axis
#      12 ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
#      13 ax.grid(linestyle='-', linewidth='0.5', color='#6DB0C7') #set only major grid
#
# NameError: name 'FormatStrFormatter' is not defined

# %%
geo1 = data.loc[data['NAME'] == 'Gallatin']
geo2 = data.loc[data['NAME'] == 'Sumner County']

# %%
x1 = geo1['Year']
y1 = geo1['Population']
title = 'Comparative Population Growth\n 2000 - 2020'
xlabel = 'Year'
ylabel = 'Population'
# ylimlow = 20000
# ylimhigh = 45500
txt = 'Citation: 2000, 2010, and 2020 Decennial Census'

x2 = geo2['Year']
y2 = geo2['Population']

# %%
fig, ax = plt.subplots(figsize = (10, 5))
ax.plot(x1, y1,
        marker = 'o', #marker
        color = '#00263E', #marker color
        alpha = 0.5, #transparency
        linewidth = 2,
        label = 'Gallatin'
       )
ax.plot(x2, y2,
        marker = 'o', #marker
        color = '#EB7525', #marker color
        alpha = 0.5, #transparency
        linewidth = 2, 
        label = 'Sumner County'
       )
ax.set(title = title, 
      xlabel = xlabel, 
      ylabel = ylabel)
ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f')) #set the decimal tolerance for x axis
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
ax.grid(linestyle='-', linewidth='0.5', color='#6DB0C7') #set only major grid
#ax.set_ylim(ylimlow, ylimhigh)
ax.tick_params(axis='both', which='major', pad=5)
ax.set_facecolor('#F4F8F9')
ax.legend(loc = 7, facecolor = '#F4F8F9', edgecolor = '#7B7E85')
#citation label
fig.text(.4, .0009, txt, ha='right')
#try labels
for j, k in zip(x1, y1):
    label = "{:,.0f}".format(k)
    plt.annotate(label, 
                (j, k), 
                textcoords = 'offset points', 
                xytext = (0, 10), 
                ha = 'center')
#try labels
for j, k in zip(x2, y2):
    label = "{:,.0f}".format(k)
    plt.annotate(label, 
                (j, k), 
                textcoords = 'offset points', 
                xytext = (0, -20), 
                ha = 'center')
#ax.tight_layout()
#plt.savefig('formattest.png')
plt.show();

# %% [markdown]
# ### Try for bidirectional bar chart for population pyramid

# %%
poppyr = data.loc[data['']]
