# %% [markdown]
# ###### Imports and Settings

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import requests
import io
import pickle
import matplotlib.pyplot as plt
from collections import deque
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)

# %% [markdown]
# ###### Functions

# %%
#function for percent of whole
def percent(x, y):
    try:
        return round((x/y)*100, 2)
    except ZeroDivisionError:
        return 666
#function for population density
def populationdensity(x, y):
    try:
        return round(x/y, 2)
    except ZeroDivisionError:
        return 666

# %% [markdown]
# # Comprehensive Plan Data Pull
#
# The following API calls are designed to streamline the data pulls for the comprehensive plans for any geography. For the sake of simplicity, there are three separate documents for ACS variables, Decennial 2000 SF3 variables, and Decennial SF1 variables. This document contains Decennial SF1 variables.

# %%
#to read in... rb is read bite
with open('api_keys.pkl', 'rb') as keys_file:
        keys_dict_2 = pickle.load(keys_file)

# %%
#create a variable that contains your api key
api_key = keys_dict_2['CENSUS']

# %%
GNRC = ['161', #Stewart
       '125', #Montgomery
       '083', #Houston
       '085', #Humphreys
       '043', #Dickson
       '021', #Cheatham
       '147', #Robertson
       '165', #Sumner
       '037', #Davidson
       '189', #Wilson
       '169', #Trousdale
       '187', #Williamson
       '149', #Rutherford
       '119'] #Maury

# %%
YEARS = ['2000','2010']

# %% [markdown]
# ## Read In Data Guide

# %% [markdown]
# The "head" should never be more than 2 variables, and the "tail" never more than 2. Since we can pull 50 variables at once this means that we can systematically program in 46 variables for each pull, so that's:
# + dg1: ID's 1 - 46
# + dg2: ID's 47-92
# + dg3: ID's 93-138
# + dg4: ID's 139-184
# + dg5: ID's 185-230
# + dg6: ID's 231-276
# + dg7: ID's 277-322
# + dg8: ID's 323-368
# + dg9: ID's 369-414
# + dg10: ID's 415-460
# + dg11: ID's 461-506
# + dg12: ID's 507-552
# + dg13: ID's 553-598
# + dg14: ID's 599-644
# + dg15: ID's 645-690
# + dg16: ID's 691-736
# + dg17: ID's 737-782
# + dg18: ID's 783-828
# **This data guide stops at ID 783 as of 5/18/2022.**

# %% [markdown]
# ### SF1

# %%
dataguide = pd.read_csv('../DATA GUIDE SF1.csv', dtype = str)
dataguide['ID'] = dataguide['ID'].astype(int)

# %%
dg1 = dataguide[dataguide['ID'].between(1, 46)]
dg2 = dataguide[dataguide['ID'].between(47, 92)]

# %%
# ONE
# listparams
head1 = 'NAME'
head2 = 'GEO_ID'
tail_cols1 = 'StateFIPS'
tail_cols2 = 'CountyFIPS'
#make variables list
var_list = list(dg1['SF1 Variable'])
#add stuff to variables list
var_list = deque(var_list)
var_list.appendleft(head2)
var_list.appendleft(head1)
var_list = list(var_list)
#make columns list
col_list = list(dg1['Column Name'])
#add stuff to columns list
col_list.append(tail_cols1)
col_list.append(tail_cols2)
col_list = deque(col_list)
col_list.appendleft(head2)
col_list.appendleft(head1)
col_list = list(col_list)
#add stuff to columns list
data_appended = []
for i in YEARS:
    url_str= 'https://api.census.gov/data/{}/dec/sf1?key='.format(i)+api_key
    predicates= {}
    get_vars= var_list
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:*"
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = col_list
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype=str)
    #data['Year'] = '{}'.format(i)
    data = data.loc[data['CountyFIPS'].isin(GNRC)]
    data = data.add_suffix('{}'.format(i))
    data_appended.append(data)
data_appended = pd.concat(data_appended).reset_index(drop = True)
#data_appended = data_appended.loc[data_appended['CountyFIPS'].isin(GNRC)].reset_index(drop = True)
one = data_appended
print('Okay Finished')
# Out:
# Okay Finished

# %%
# ONE
# listparams
head1 = 'NAME'
head2 = 'GEO_ID'
tail_cols1 = 'StateFIPS'
tail_cols2 = 'CountyFIPS'
#make variables list
var_list = list(dg1['SF1 Variable'])
#add stuff to variables list
var_list = deque(var_list)
var_list.appendleft(head2)
var_list.appendleft(head1)
var_list = list(var_list)
#make columns list
col_list = list(dg1['Column Name'])
#add stuff to columns list
col_list.append(tail_cols1)
col_list.append(tail_cols2)
col_list = deque(col_list)
col_list.appendleft(head2)
col_list.appendleft(head1)
col_list = list(col_list)
#add stuff to columns list
data_appended = []
for i in YEARS:
    url_str= 'https://api.census.gov/data/{}/dec/sf1?key='.format(i)+api_key
    predicates= {}
    get_vars= var_list
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:*"
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = col_list
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype=str)
    #data['Year'] = '{}'.format(i)
    data = data.loc[data['CountyFIPS'].isin(GNRC)]
    data = data.add_suffix('{}'.format(i))
    data_appended.append(data)
data_appended = pd.concat(data_appended).reset_index(drop = True)
#data_appended = data_appended.loc[data_appended['CountyFIPS'].isin(GNRC)].reset_index(drop = True)
one = data_appended
print('Okay Finished')
# Out:
# Okay Finished

# %%
one.head(20)
# Out:
#                         NAME2000      GEO_ID2000 pop2000 agebysex_total_series2000 age_total_male2000 age_m_u52000 age_m_5to92000 age_m_10to142000  \
# 0     Cheatham County, Tennessee  0500000US47021   35912                     35912              17981         1372           1473             1487
# 1     Davidson County, Tennessee  0500000US47037  569891                    569891             275865        19466          18200            17089
# 2      Dickson County, Tennessee  0500000US47043   43156                     43156              21158         1538           1686             1726
# 3      Houston County, Tennessee  0500000US47083    8088                      8088               3999          268            311              266
# 4    Humphreys County, Tennessee  0500000US47085   17929                     17929               8819          567            610              660
# 5        Maury County, Tennessee  0500000US47119   69498                     69498              33782         2444           2512             2746
# 6   Montgomery County, Tennessee  0500000US47125  134768                    134768              67775         5901           5751             5340
# 7    Robertson County, Tennessee  0500000US47147   54433                     54433              27051         1897           2112             2267
# 8   Rutherford County, Tennessee  0500000US47149  182023                    182023              90585         7027           7045             6692
# 9      Stewart County, Tennessee  0500000US47161   12370                     12370               6158          374            430              465
# 10      Sumner County, Tennessee  0500000US47165  130449                    130449              63876         4567           4862             5077
# 11   Trousdale County, Tennessee  0500000US47169    7259                      7259               3573          217            286              264
# 12  Williamson County, Tennessee  0500000US47187  126638                    126638              62358         4722           5507             5676
# 13      Wilson County, Tennessee  0500000US47189   88809                     88809              43830         3074           3334             3531
# 14                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 15                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 16                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 17                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 18                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 19                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
#
#    age_m_15to172000 age_m_18to192000 age_m_202000 age_m_212000 age_m_22to242000 age_m_25to292000 age_m_30to342000 age_m_35to392000 age_m_40to442000  \
# 0               829              440          180          177              570             1133             1388             1787             1617
# 1             10120             9254         4730         4558            14070            26542            24511            24019            22218
# 2               957              557          250          236              701             1416             1594             1779             1756
# 3               174               86           36           39              146              264              256              255              300
# 4               402              214          108          110              280              537              536              651              701
# 5              1748              967          460          429             1168             2177             2249             2615             3068
# 6              2863             2128         1317         1380             4050             6608             6027             5842             5081
# 7              1285              771          358          316              997             1774             2035             2390             2299
# 8              3821             3338         1861         1899             5023             7662             7512             8195             7231
# 9               267              168           67           70              167              359              418              520              454
# 10             3242             1792          798          685             2098             4180             4614             5440             5310
# 11              163               97           54           37              123              206              232              278              285
# 12             3269             1513          531          508             1537             3300             4079             5323             6263
# 13             2007             1185          478          491             1416             2724             3261             3866             3823
# 14              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 15              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 16              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 17              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 18              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 19              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
#
#    age_m_45to492000 age_m_50to542000 age_m_55to592000 age_m_60to612000 age_m_62to642000 age_m_65to662000 age_m_67to692000 age_m_70to742000  \
# 0              1411             1231              881              284              394              221              268              389
# 1             19891            16467            11655             3874             5310             3010             4378             6608
# 2              1467             1361             1104              384              548              338              428              538
# 3               280              266              234               83              150               73              112              158
# 4               635              624              589              202              275              153              240              312
# 5              2707             2296             1661              527              718              416              654              908
# 6              3888             3200             2251              772             1070              654             1011             1224
# 7              1979             1740             1291              445              623              365              507              686
# 8              6140             5079             3708             1149             1497              811             1183             1566
# 9               456              450              366              125              173              111              191              203
# 10             4923             4455             3507             1151             1510              836             1144             1544
# 11              250              268              211               73              100               47               93              112
# 12             5704             4959             3167              953             1134              664              863             1134
# 13             3496             3153             2526              844             1059              544              767              950
# 14              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 15              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 16              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 17              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 18              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 19              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
#
#    age_m_75to792000 age_m_80to842000 age_m_85+2000 age_total_female2000 age_f_u52000 age_f_5to92000 age_f_10to142000 age_f_15to172000  \
# 0               226              135            88                17931         1187           1330             1398              854
# 1              4941             2961          1993               294026        18347          17524            16143             9558
# 2               414              242           138                21998         1437           1584             1601              957
# 3               112               77            53                 4089          273            243              298              137
# 4               225              114            74                 9110          505            597              584              357
# 5               625              396           291                35716         2322           2324             2617             1521
# 6               704              417           296                66993         5552           5335             4878             2709
# 7               470              263           181                27382         1823           2019             2027             1152
# 8              1107              635           404                91438         6629           6688             6487             3722
# 9               173               83            68                 6212          353            420              417              234
# 10             1119              600           422                66573         4266           4574             4773             2976
# 11               80               62            35                 3686          222            236              231              138
# 12              847              441           264                64280         4447           5158             5525             3046
# 13              661              369           271                44979         2964           3214             3315             1866
# 14              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 15              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 16              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 17              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 18              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 19              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
#
#    age_f_18to192000 age_f_202000 age_f_212000 age_f_22to242000 age_f_25to292000 age_f_30to342000 age_f_35to392000 age_f_40to442000 age_f_45to492000  \
# 0               369          173          182              518             1201             1487             1780             1649             1372
# 1              9399         4935         4832            14420            25950            23184            24029            23233            20978
# 2               532          246          227              744             1459             1649             1753             1828             1513
# 3                78           37           43              127              244              240              277              271              293
# 4               198           89           89              278              602              571              669              668              684
# 5               931          427          435             1262             2169             2397             2928             3123             2739
# 6              1987         1148         1168             3374             5987             5619             5840             5196             4018
# 7               623          331          315              906             1749             2123             2429             2289             2035
# 8              3520         1994         1894             4479             7340             7374             8153             7500             6162
# 9               161           42           61              187              378              391              488              499              445
# 10             1628          686          690             2108             4240             4796             5849             5619             5083
# 11               96           44           50              115              213              260              278              287              272
# 12             1277          484          455             1552             3522             4604             6232             6717             5944
# 13             1010          471          459             1310             2811             3390             4241             4039             3461
# 14              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 15              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 16              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 17              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 18              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 19              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
#
#    age_f_50to542000 age_f_55to592000 age_f_60to612000 age_f_62to642000 age_f_65to662000 age_f_67to692000 StateFIPS2000 CountyFIPS2000  \
# 0              1161              850              289              373              217              312            47            021
# 1             17698            13313             4521             6409             4016             5878            47            037
# 2              1431             1129              381              556              322              505            47            043
# 3               274              260               92              137               92              112            47            083
# 4               633              556              192              301              174              255            47            085
# 5              2316             1702              606              821              507              794            47            119
# 6              3294             2529              881             1285              779             1068            47            125
# 7              1726             1305              431              684              420              598            47            147
# 8              5102             3719             1195             1564              943             1308            47            149
# 9               397              371              144              210              121              165            47            161
# 10             4494             3753             1202             1585              947             1323            47            165
# 11              250              205               84               96               58               83            47            169
# 12             4636             2997              894             1192              679              966            47            187
# 13             3166             2417              822             1005              643              779            47            189
# 14              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 15              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 16              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 17              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 18              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 19              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
#
#                         NAME2010      GEO_ID2010 pop2010 agebysex_total_series2010 age_total_male2010 age_m_u52010 age_m_5to92010 age_m_10to142010  \
# 0                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 1                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 2                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 3                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 4                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 5                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 6                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 7                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 8                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 9                            NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 10                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 11                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 12                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 13                           NaN             NaN     NaN                       NaN                NaN          NaN            NaN              NaN
# 14  Williamson County, Tennessee  0500000US47187  183182                    183182              89336         6324           7997             8372
# 15      Wilson County, Tennessee  0500000US47189  113993                    113993              55834         3746           4118             4271
# 16     Houston County, Tennessee  0500000US47083    8426                      8426               4144          245            304              287
# 17   Humphreys County, Tennessee  0500000US47085   18538                     18538               9115          539            569              627
# 18       Maury County, Tennessee  0500000US47119   80956                     80956              39155         3021           2702             2699
# 19  Montgomery County, Tennessee  0500000US47125  172331                    172331              84454         7803           6754             6257
#
#    age_m_15to172010 age_m_18to192010 age_m_202010 age_m_212010 age_m_22to242010 age_m_25to292010 age_m_30to342010 age_m_35to392010 age_m_40to442010  \
# 0               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 1               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 2               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 3               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 4               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 5               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 6               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 7               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 8               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 9               NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 10              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 11              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 12              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 13              NaN              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN
# 14             4712             2098          684          621             2155             3682             4755             6623             7440
# 15             2473             1480          684          534             1590             2872             3382             4097             4273
# 16              186              124           48           45              113              214              228              242              264
# 17              460              266           92          106              263              433              532              592              579
# 18             1668             1084          477          436             1349             2583             2576             2588             2498
# 19             3697             2498         1435         1507             5140             8306             6592             5883             5495
#
#    age_m_45to492010 age_m_50to542010 age_m_55to592010 age_m_60to612010 age_m_62to642010 age_m_65to662010 age_m_67to692010 age_m_70to742010  \
# 0               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 1               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 2               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 3               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 4               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 5               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 6               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 7               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 8               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 9               NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 10              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 11              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 12              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 13              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 14             7677             7402             6010             2131             2793             1405             1693             1930
# 15             4663             4373             3739             1374             1924             1062             1406             1731
# 16              282              317              295              104              169              110              140              180
# 17              665              682              639              273              345              211              345              378
# 18             2752             3193             2763              965             1396              686              929             1120
# 19             5379             4839             3804             1367             1746              909             1202             1563
#
#    age_m_75to792010 age_m_80to842010 age_m_85+2010 age_total_female2010 age_f_u52010 age_f_5to92010 age_f_10to142010 age_f_15to172010  \
# 0               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 1               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 2               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 3               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 4               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 5               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 6               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 7               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 8               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 9               NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 10              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 11              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 12              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 13              NaN              NaN           NaN                  NaN          NaN            NaN              NaN              NaN
# 14             1297              893           642                93846         6039           7718             7870             4597
# 15             1061              566           415                58159         3572           3933             4086             2362
# 16              117               86            44                 4282          228            276              298              168
# 17              252              172            95                 9423          502            613              596              387
# 18              795              518           357                41801         2789           2697             2610             1471
# 19             1195              679           404                87877         7526           6548             6027             3602
#
#    age_f_18to192010 age_f_202010 age_f_212010 age_f_22to242010 age_f_25to292010 age_f_30to342010 age_f_35to392010 age_f_40to442010 age_f_45to492010  \
# 0               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 1               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 2               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 3               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 4               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 5               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 6               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 7               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 8               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 9               NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 10              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 11              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 12              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 13              NaN          NaN          NaN              NaN              NaN              NaN              NaN              NaN              NaN
# 14             1705          528          607             2188             4177             5558             7285             8076             8621
# 15             1273          554          543             1639             3158             3695             4283             4501             4988
# 16               92           45           45              133              202              223              268              276              307
# 17              213           99           77              260              471              521              595              602              681
# 18              951          477          420             1467             2758             2817             2559             2645             3215
# 19             2756         1583         1545             4994             8074             6722             6281             5630             5778
#
#    age_f_50to542010 age_f_55to592010 age_f_60to612010 age_f_62to642010 age_f_65to662010 age_f_67to692010 StateFIPS2010 CountyFIPS2010
# 0               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 1               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 2               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 3               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 4               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 5               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 6               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 7               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 8               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 9               NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 10              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 11              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 12              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 13              NaN              NaN              NaN              NaN              NaN              NaN           NaN            NaN
# 14             7767             6229             2141             2793             1485             1770            47            187
# 15             4548             3864             1439             2094             1128             1498            47            189
# 16              281              329              120              165              107              141            47            083
# 17              693              720              261              380              217              308            47            085
# 18             3364             2984             1078             1425              747             1022            47            119
# 19             5310             4198             1505             1959             1062             1441            47            125
