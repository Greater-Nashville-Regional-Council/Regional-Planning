# %% [markdown]
# ### OSMnx contributes five primary capabilities
# + enables automated and on-demand downloading of political boundary geometries
# + can automate and customize the downloading of street networks from OpenStreetMap and construct them into multidigraphs
# + can correct and simplify network topology
# + can save/load street networds to/from disk in various file formats
# + has built-in functions to analyze street networks, calculate routs, project and visualize networks, and quickly and consistently calculate various metric and topological measures

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
from descartes import PolygonPatch
from shapely.geometry import Point, LineString, Polygon
import sklearn
# %matplotlib inline
ox.config(log_console=True)
ox.__version__
pd.set_option('display.max_rows', 1000); pd.set_option('display.max_columns', 1000); pd.set_option('display.width', 1000)
# Out:
# C:\Users\jmccall\AppData\Local\anaconda3\envs\openstreets\lib\site-packages\osmnx\utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(

# %%
pipwin install gdal
# Out:
#   Cell In[6], line 1
#     pipwin install gdal
#            ^
# SyntaxError: invalid syntax

# %%
rides = pd.read_csv('../data/accessrides.csv')

# %%
rides.head()
# Out:
#      Type  Client ID      Time                       Date      Time Stamp
# 0  Pickup         78  15:00:00  Saturday, January 1, 2022  1/1/2022 15:00  \
# 1  Pickup         78  18:45:00  Saturday, January 1, 2022  1/1/2022 18:45
# 2  Pickup       7096   7:00:00  Saturday, January 1, 2022   1/1/2022 7:00
# 3  Pickup       9607  14:15:00  Saturday, January 1, 2022  1/1/2022 14:15
# 4  Pickup       9988  12:45:00  Saturday, January 1, 2022  1/1/2022 12:45
#
#          LAT       LONG
# 0  36.145059 -86.812360
# 1  36.194334 -86.618303
# 2  36.143799 -86.752940
# 3  36.215131 -86.600926
# 4  36.145059 -86.812360

# %%
gdf = gpd.GeoDataFrame(rides, geometry=gpd.points_from_xy(rides.LONG, rides.LAT), crs = 'NAD83')

# %%
gdf['LAT'] = gdf['LAT'].astype(str)
gdf['LONG'] = gdf['LONG'].astype(str)

# %%
gdf.tail()
# Out:
#            Type  Client ID      Time                         Date
# 491117  Dropoff      27371   5:30:00  Saturday, December 31, 2022  \
# 491118  Dropoff      27373   6:15:00  Saturday, December 31, 2022
# 491119  Dropoff      27373  12:00:00  Saturday, December 31, 2022
# 491120  Dropoff      27426   6:45:00  Saturday, December 31, 2022
# 491121  Dropoff      27426  11:15:00  Saturday, December 31, 2022
#
#               Time Stamp        LAT        LONG                    geometry
# 491117   12/31/2022 5:30  36.138703  -86.801373  POINT (-86.80137 36.13870)  \
# 491118   12/31/2022 6:15  36.162768  -86.679763  POINT (-86.67976 36.16277)
# 491119  12/31/2022 12:00  36.248777  -86.756963  POINT (-86.75696 36.24878)
# 491120   12/31/2022 6:45  36.232634  -86.755149  POINT (-86.75515 36.23263)
# 491121  12/31/2022 11:15  36.302074  -86.737109  POINT (-86.73711 36.30207)
#
#                          Points            LatLongPoints
# 491117  (-86.801373, 36.138703)  (36.138703, -86.801373)
# 491118  (-86.679763, 36.162768)  (36.162768, -86.679763)
# 491119  (-86.756963, 36.248777)  (36.248777, -86.756963)
# 491120  (-86.755149, 36.232634)  (36.232634, -86.755149)
# 491121  (-86.737109, 36.302074)  (36.302074, -86.737109)

# %%
gdf['Points'] = '(' + gdf['LONG'] + ', ' + gdf['LAT'] + ')'
gdf['LatLongPoints'] = '(' + gdf['LAT'] + ', ' + gdf['LONG'] + ')'

# %%
points = list(gdf['geometry'].unique())

# %%
points
# Out:
# [<shapely.geometry.point.Point at 0x248b64ae9a0>,
#  <shapely.geometry.point.Point at 0x248382995b0>,
#  <shapely.geometry.point.Point at 0x24838299070>,
#  <shapely.geometry.point.Point at 0x248dd12f520>,
#  <shapely.geometry.point.Point at 0x248dd12feb0>,
#  <shapely.geometry.point.Point at 0x2491bfd3370>,
#  <shapely.geometry.point.Point at 0x2491bfd3d90>,
#  <shapely.geometry.point.Point at 0x2483c5f5e80>,
#  <shapely.geometry.point.Point at 0x248200b2be0>,
#  <shapely.geometry.point.Point at 0x248200b21c0>,
#  <shapely.geometry.point.Point at 0x248200b2d30>,
#  <shapely.geometry.point.Point at 0x248200b2850>,
#  <shapely.geometry.point.Point at 0x248200b2b20>,
#  <shapely.geometry.point.Point at 0x248200b2cd0>,
#  <shapely.geometry.point.Point at 0x248200b29d0>,
#  <shapely.geometry.point.Point at 0x248200b24c0>,
#  <shapely.geometry.point.Point at 0x248200b2460>,
#  <shapely.geometry.point.Point at 0x248200b2f70>,
#  <shapely.geometry.point.Point at 0x248200b2820>,
#  <shapely.geometry.point.Point at 0x248200b2670>,
#  <shapely.geometry.point.Point at 0x248200b29a0>,
#  <shapely.geometry.point.Point at 0x248200b2fa0>,
#  <shapely.geometry.point.Point at 0x248200b2400>,
#  <shapely.geometry.point.Point at 0x248200b2970>,
#  <shapely.geometry.point.Point at 0x248200b2070>,
#  <shapely.geometry.point.Point at 0x248200b28b0>,
#  <shapely.geometry.point.Point at 0x248200b2c10>,
#  <shapely.geometry.point.Point at 0x248200b2430>,
#  <shapely.geometry.point.Point at 0x248200b2c40>,
#  <shapely.geometry.point.Point at 0x248200b2880>,
#  <shapely.geometry.point.Point at 0x248200b2700>,
#  <shapely.geometry.point.Point at 0x248200b2640>,
#  <shapely.geometry.point.Point at 0x248200b23d0>,
#  <shapely.geometry.point.Point at 0x248200b2af0>,
#  <shapely.geometry.point.Point at 0x248200b27f0>,
#  <shapely.geometry.point.Point at 0x248200b2ee0>,
#  <shapely.geometry.point.Point at 0x248200b2f40>,
#  <shapely.geometry.point.Point at 0x248a2e9a040>,
#  <shapely.geometry.point.Point at 0x248a2e9a070>,
#  <shapely.geometry.point.Point at 0x248a2e9a0a0>,
#  <shapely.geometry.point.Point at 0x248a2e9a0d0>,
#  <shapely.geometry.point.Point at 0x248a2e9a100>,
#  <shapely.geometry.point.Point at 0x248a2e9a130>,
#  <shapely.geometry.point.Point at 0x248a2e9a160>,
#  <shapely.geometry.point.Point at 0x248a2e9a190>,
#  <shapely.geometry.point.Point at 0x248a2e9a1c0>,
#  <shapely.geometry.point.Point at 0x248a2e9a1f0>,
#  <shapely.geometry.point.Point at 0x248a2e9a220>,
#  <shapely.geometry.point.Point at 0x248a2e9a250>,
#  <shapely.geometry.point.Point at 0x248a2e9a280>,
#  <shapely.geometry.point.Point at 0x248a2e9a2b0>,
#  <shapely.geometry.point.Point at 0x248a2e9a2e0>,
#  <shapely.geometry.point.Point at 0x248a2e9a310>,
#  <shapely.geometry.point.Point at 0x248a2e9a340>,
#  <shapely.geometry.point.Point at 0x248a2e9a370>,
#  <shapely.geometry.point.Point at 0x248a2e9a3a0>,
#  <shapely.geometry.point.Point at 0x248a2e9a3d0>,
#  <shapely.geometry.point.Point at 0x248a2e9a400>,
#  <shapely.geometry.point.Point at 0x248a2e9a430>,
#  <shapely.geometry.point.Point at 0x248a2e9a460>,
#  <shapely.geometry.point.Point at 0x248a2e9a490>,
#  <shapely.geometry.point.Point at 0x248a2e9a4c0>,
#  <shapely.geometry.point.Point at 0x248a2e9a4f0>,
#  <shapely.geometry.point.Point at 0x248a2e9a520>,
#  <shapely.geometry.point.Point at 0x248a2e9a550>,
#  <shapely.geometry.point.Point at 0x248a2e9a580>,
#  <shapely.geometry.point.Point at 0x248a2e9a5b0>,
#  <shapely.geometry.point.Point at 0x248a2e9a5e0>,
#  <shapely.geometry.point.Point at 0x248a2e9a610>,
#  <shapely.geometry.point.Point at 0x248a2e9a640>,
#  <shapely.geometry.point.Point at 0x248a2e9a670>,
#  <shapely.geometry.point.Point at 0x248a2e9a6a0>,
#  <shapely.geometry.point.Point at 0x248a2e9a6d0>,
#  <shapely.geometry.point.Point at 0x248a2e9a700>,
#  <shapely.geometry.point.Point at 0x248a2e9a730>,
#  <shapely.geometry.point.Point at 0x248a2e9a760>,
#  <shapely.geometry.point.Point at 0x248a2e9a790>,
#  <shapely.geometry.point.Point at 0x248a2e9a7c0>,
#  <shapely.geometry.point.Point at 0x248a2e9a7f0>,
#  <shapely.geometry.point.Point at 0x248a2e9a820>,
#  <shapely.geometry.point.Point at 0x248a2e9a850>,
#  <shapely.geometry.point.Point at 0x248a2e9a880>,
#  <shapely.geometry.point.Point at 0x248a2e9a8b0>,
#  <shapely.geometry.point.Point at 0x248a2e9a8e0>,
#  <shapely.geometry.point.Point at 0x248a2e9a910>,
#  <shapely.geometry.point.Point at 0x248a2e9a940>,
#  <shapely.geometry.point.Point at 0x248a2e9a970>,
#  <shapely.geometry.point.Point at 0x248a2e9a9a0>,
#  <shapely.geometry.point.Point at 0x248a2e9a9d0>,
#  <shapely.geometry.point.Point at 0x248a2e9aa00>,
#  <shapely.geometry.point.Point at 0x248a2e9aa30>,
#  <shapely.geometry.point.Point at 0x248a2e9aa60>,
#  <shapely.geometry.point.Point at 0x248a2e9aa90>,
#  <shapely.geometry.point.Point at 0x248a2e9aac0>,
#  <shapely.geometry.point.Point at 0x248a2e9aaf0>,
#  <shapely.geometry.point.Point at 0x248a2e9ab20>,
#  <shapely.geometry.point.Point at 0x248a2e9ab50>,
#  <shapely.geometry.point.Point at 0x248a2e9ab80>,
#  <shapely.geometry.point.Point at 0x248a2e9abb0>,
#  <shapely.geometry.point.Point at 0x248a2e9abe0>,
#  <shapely.geometry.point.Point at 0x248a2e9ac10>,
#  <shapely.geometry.point.Point at 0x248a2e9ac40>,
#  <shapely.geometry.point.Point at 0x248a2e9ac70>,
#  <shapely.geometry.point.Point at 0x248a2e9aca0>,
#  <shapely.geometry.point.Point at 0x248a2e9acd0>,
#  <shapely.geometry.point.Point at 0x248a2e9ad00>,
#  <shapely.geometry.point.Point at 0x248a2e9ad30>,
#  <shapely.geometry.point.Point at 0x248a2e9ad60>,
#  <shapely.geometry.point.Point at 0x248a2e9ad90>,
#  <shapely.geometry.point.Point at 0x248a2e9adc0>,
#  <shapely.geometry.point.Point at 0x248a2e9adf0>,
#  <shapely.geometry.point.Point at 0x248a2e9ae20>,
#  <shapely.geometry.point.Point at 0x248a2e9ae50>,
#  <shapely.geometry.point.Point at 0x248a2e9ae80>,
#  <shapely.geometry.point.Point at 0x248a2e9aeb0>,
#  <shapely.geometry.point.Point at 0x248a2e9aee0>,
#  <shapely.geometry.point.Point at 0x248a2e9af10>,
#  <shapely.geometry.point.Point at 0x248a2e9af40>,
#  <shapely.geometry.point.Point at 0x248a2e9af70>,
#  <shapely.geometry.point.Point at 0x248a2e9afa0>,
#  <shapely.geometry.point.Point at 0x248a2e9afd0>,
#  <shapely.geometry.point.Point at 0x2482008f040>,
#  <shapely.geometry.point.Point at 0x2482008f070>,
#  <shapely.geometry.point.Point at 0x2482008f0a0>,
#  <shapely.geometry.point.Point at 0x2482008f0d0>,
#  <shapely.geometry.point.Point at 0x2482008f100>,
#  <shapely.geometry.point.Point at 0x2482008f160>,
#  <shapely.geometry.point.Point at 0x2482008f130>,
#  <shapely.geometry.point.Point at 0x2482008f190>,
#  <shapely.geometry.point.Point at 0x2482008f1c0>,
#  <shapely.geometry.point.Point at 0x2482008f1f0>,
#  <shapely.geometry.point.Point at 0x2482008f220>,
#  <shapely.geometry.point.Point at 0x2482008f250>,
#  <shapely.geometry.point.Point at 0x2482008f280>,
#  <shapely.geometry.point.Point at 0x2482008f2b0>,
#  <shapely.geometry.point.Point at 0x2482008f2e0>,
#  <shapely.geometry.point.Point at 0x2482008f310>,
#  <shapely.geometry.point.Point at 0x2482008f340>,
#  <shapely.geometry.point.Point at 0x2482008f370>,
#  <shapely.geometry.point.Point at 0x2482008f3a0>,
#  <shapely.geometry.point.Point at 0x2482008f3d0>,
#  <shapely.geometry.point.Point at 0x2482008f400>,
#  <shapely.geometry.point.Point at 0x2482008f430>,
#  <shapely.geometry.point.Point at 0x2482008f460>,
#  <shapely.geometry.point.Point at 0x2482008f490>,
#  <shapely.geometry.point.Point at 0x2482008f4c0>,
#  <shapely.geometry.point.Point at 0x2482008f4f0>,
#  <shapely.geometry.point.Point at 0x2482008f520>,
#  <shapely.geometry.point.Point at 0x2482008f550>,
#  <shapely.geometry.point.Point at 0x2482008f580>,
#  <shapely.geometry.point.Point at 0x2482008f5b0>,
#  <shapely.geometry.point.Point at 0x2482008f5e0>,
#  <shapely.geometry.point.Point at 0x2482008f610>,
#  <shapely.geometry.point.Point at 0x2482008f640>,
#  <shapely.geometry.point.Point at 0x2482008f670>,
#  <shapely.geometry.point.Point at 0x2482008f6a0>,
#  <shapely.geometry.point.Point at 0x2482008f6d0>,
#  <shapely.geometry.point.Point at 0x2482008f700>,
#  <shapely.geometry.point.Point at 0x2482008f730>,
#  <shapely.geometry.point.Point at 0x2482008f760>,
#  <shapely.geometry.point.Point at 0x2482008f790>,
#  <shapely.geometry.point.Point at 0x2482008f7c0>,
#  <shapely.geometry.point.Point at 0x2482008f7f0>,
#  <shapely.geometry.point.Point at 0x2482008f820>,
#  <shapely.geometry.point.Point at 0x2482008f850>,
#  <shapely.geometry.point.Point at 0x2482008f880>,
#  <shapely.geometry.point.Point at 0x2482008f8b0>,
#  <shapely.geometry.point.Point at 0x2482008f8e0>,
#  <shapely.geometry.point.Point at 0x2482008f910>,
#  <shapely.geometry.point.Point at 0x2482008f940>,
#  <shapely.geometry.point.Point at 0x2482008f970>,
#  <shapely.geometry.point.Point at 0x2482008f9a0>,
#  <shapely.geometry.point.Point at 0x2482008f9d0>,
#  <shapely.geometry.point.Point at 0x2482008fa00>,
#  <shapely.geometry.point.Point at 0x2482008fa30>,
#  <shapely.geometry.point.Point at 0x2482008fa60>,
#  <shapely.geometry.point.Point at 0x2482008fa90>,
#  <shapely.geometry.point.Point at 0x2482008fac0>,
#  <shapely.geometry.point.Point at 0x2482008faf0>,
#  <shapely.geometry.point.Point at 0x2482008fb20>,
#  <shapely.geometry.point.Point at 0x2482008fb50>,
#  <shapely.geometry.point.Point at 0x2482008fb80>,
#  <shapely.geometry.point.Point at 0x2482008fbb0>,
#  <shapely.geometry.point.Point at 0x2482008fbe0>,
#  <shapely.geometry.point.Point at 0x2482008fc10>,
#  <shapely.geometry.point.Point at 0x2482008fc40>,
#  <shapely.geometry.point.Point at 0x2482008fc70>,
#  <shapely.geometry.point.Point at 0x2482008fca0>,
#  <shapely.geometry.point.Point at 0x2482008fcd0>,
#  <shapely.geometry.point.Point at 0x2482008fd00>,
#  <shapely.geometry.point.Point at 0x2482008fd30>,
#  <shapely.geometry.point.Point at 0x2482008fd60>,
#  <shapely.geometry.point.Point at 0x2482008fd90>,
#  <shapely.geometry.point.Point at 0x2482008fdc0>,
#  <shapely.geometry.point.Point at 0x2482008fdf0>,
#  <shapely.geometry.point.Point at 0x2482008fe20>,
#  <shapely.geometry.point.Point at 0x2482008fe50>,
#  <shapely.geometry.point.Point at 0x2482008fe80>,
#  <shapely.geometry.point.Point at 0x2482008feb0>,
#  <shapely.geometry.point.Point at 0x2482008fee0>,
#  <shapely.geometry.point.Point at 0x2482008ff10>,
#  <shapely.geometry.point.Point at 0x2482008ff40>,
#  <shapely.geometry.point.Point at 0x2482008ff70>,
#  <shapely.geometry.point.Point at 0x2482008ffa0>,
#  <shapely.geometry.point.Point at 0x2482008ffd0>,
#  <shapely.geometry.point.Point at 0x248a7a96040>,
#  <shapely.geometry.point.Point at 0x248a7a96070>,
#  <shapely.geometry.point.Point at 0x248a7a960a0>,
#  <shapely.geometry.point.Point at 0x248a7a960d0>,
#  <shapely.geometry.point.Point at 0x248a7a96100>,
#  <shapely.geometry.point.Point at 0x248a7a96130>,
#  <shapely.geometry.point.Point at 0x248a7a96160>,
#  <shapely.geometry.point.Point at 0x248a7a96190>,
#  <shapely.geometry.point.Point at 0x248a7a961c0>,
#  <shapely.geometry.point.Point at 0x248a7a961f0>,
#  <shapely.geometry.point.Point at 0x248a7a96220>,
#  <shapely.geometry.point.Point at 0x248a7a96250>,
#  <shapely.geometry.point.Point at 0x248a7a96280>,
#  <shapely.geometry.point.Point at 0x248a7a962b0>,
#  <shapely.geometry.point.Point at 0x248a7a962e0>,
#  <shapely.geometry.point.Point at 0x248a7a96310>,
#  <shapely.geometry.point.Point at 0x248a7a96340>,
#  <shapely.geometry.point.Point at 0x248a7a96370>,
#  <shapely.geometry.point.Point at 0x248a7a963a0>,
#  <shapely.geometry.point.Point at 0x248a7a963d0>,
#  <shapely.geometry.point.Point at 0x248a7a96400>,
#  <shapely.geometry.point.Point at 0x248a7a96430>,
#  <shapely.geometry.point.Point at 0x248a7a96460>,
#  <shapely.geometry.point.Point at 0x248a7a96490>,
#  <shapely.geometry.point.Point at 0x248a7a964c0>,
#  <shapely.geometry.point.Point at 0x248a7a964f0>,
#  <shapely.geometry.point.Point at 0x248a7a96520>,
#  <shapely.geometry.point.Point at 0x248a7a96550>,
#  <shapely.geometry.point.Point at 0x248a7a96580>,
#  <shapely.geometry.point.Point at 0x248a7a965b0>,
#  <shapely.geometry.point.Point at 0x248a7a965e0>,
#  <shapely.geometry.point.Point at 0x248a7a96610>,
#  <shapely.geometry.point.Point at 0x248a7a96640>,
#  <shapely.geometry.point.Point at 0x248a7a96670>,
#  <shapely.geometry.point.Point at 0x248a7a966a0>,
#  <shapely.geometry.point.Point at 0x248a7a966d0>,
#  <shapely.geometry.point.Point at 0x248a7a96700>,
#  <shapely.geometry.point.Point at 0x248a7a96730>,
#  <shapely.geometry.point.Point at 0x248a7a96760>,
#  <shapely.geometry.point.Point at 0x248a7a96790>,
#  <shapely.geometry.point.Point at 0x248a7a967c0>,
#  <shapely.geometry.point.Point at 0x248a7a967f0>,
#  <shapely.geometry.point.Point at 0x248a7a96820>,
#  <shapely.geometry.point.Point at 0x248a7a96850>,
#  <shapely.geometry.point.Point at 0x248a7a96880>,
#  <shapely.geometry.point.Point at 0x248a7a968b0>,
#  <shapely.geometry.point.Point at 0x248a7a968e0>,
#  <shapely.geometry.point.Point at 0x248a7a96910>,
#  <shapely.geometry.point.Point at 0x248a7a96940>,
#  <shapely.geometry.point.Point at 0x248a7a96970>,
#  <shapely.geometry.point.Point at 0x248a7a969a0>,
#  <shapely.geometry.point.Point at 0x248a7a969d0>,
#  <shapely.geometry.point.Point at 0x248a7a96a00>,
#  <shapely.geometry.point.Point at 0x248a7a96a30>,
#  <shapely.geometry.point.Point at 0x248a7a96a60>,
#  <shapely.geometry.point.Point at 0x248a7a96a90>,
#  <shapely.geometry.point.Point at 0x248a7a96ac0>,
#  <shapely.geometry.point.Point at 0x248a7a96af0>,
#  <shapely.geometry.point.Point at 0x248a7a96b20>,
#  <shapely.geometry.point.Point at 0x248a7a96b50>,
#  <shapely.geometry.point.Point at 0x248a7a96b80>,
#  <shapely.geometry.point.Point at 0x248a7a96bb0>,
#  <shapely.geometry.point.Point at 0x248a7a96be0>,
#  <shapely.geometry.point.Point at 0x248a7a96c10>,
#  <shapely.geometry.point.Point at 0x248a7a96c40>,
#  <shapely.geometry.point.Point at 0x248a7a96c70>,
#  <shapely.geometry.point.Point at 0x248a7a96ca0>,
#  <shapely.geometry.point.Point at 0x248a7a96cd0>,
#  <shapely.geometry.point.Point at 0x248a7a96d00>,
#  <shapely.geometry.point.Point at 0x248a7a96d30>,
#  <shapely.geometry.point.Point at 0x248a7a96d60>,
#  <shapely.geometry.point.Point at 0x248a7a96d90>,
#  <shapely.geometry.point.Point at 0x248a7a96dc0>,
#  <shapely.geometry.point.Point at 0x248a7a96df0>,
#  <shapely.geometry.point.Point at 0x248a7a96e20>,
#  <shapely.geometry.point.Point at 0x248a7a96e50>,
#  <shapely.geometry.point.Point at 0x248a7a96e80>,
#  <shapely.geometry.point.Point at 0x248a7a96eb0>,
#  <shapely.geometry.point.Point at 0x248a7a96ee0>,
#  <shapely.geometry.point.Point at 0x248a7a96f10>,
#  <shapely.geometry.point.Point at 0x248a7a96f40>,
#  <shapely.geometry.point.Point at 0x248a7a96f70>,
#  <shapely.geometry.point.Point at 0x248a7a96fa0>,
#  <shapely.geometry.point.Point at 0x248a7a96fd0>,
#  <shapely.geometry.point.Point at 0x248a7ab80a0>,
#  <shapely.geometry.point.Point at 0x248a7ab8040>,
#  <shapely.geometry.point.Point at 0x248a7ab8070>,
#  <shapely.geometry.point.Point at 0x248a7ab80d0>,
#  <shapely.geometry.point.Point at 0x248a7ab8100>,
#  <shapely.geometry.point.Point at 0x248a7ab8130>,
#  <shapely.geometry.point.Point at 0x248a7ab8160>,
#  <shapely.geometry.point.Point at 0x248a7ab8190>,
#  <shapely.geometry.point.Point at 0x248a7ab81c0>,
#  <shapely.geometry.point.Point at 0x248a7ab81f0>,
#  <shapely.geometry.point.Point at 0x248a7ab8220>,
#  <shapely.geometry.point.Point at 0x248a7ab8250>,
#  <shapely.geometry.point.Point at 0x248a7ab8280>,
#  <shapely.geometry.point.Point at 0x248a7ab82b0>,
#  <shapely.geometry.point.Point at 0x248a7ab82e0>,
#  <shapely.geometry.point.Point at 0x248a7ab8310>,
#  <shapely.geometry.point.Point at 0x248a7ab8340>,
#  <shapely.geometry.point.Point at 0x248a7ab8370>,
#  <shapely.geometry.point.Point at 0x248a7ab83a0>,
#  <shapely.geometry.point.Point at 0x248a7ab83d0>,
#  <shapely.geometry.point.Point at 0x248a7ab8400>,
#  <shapely.geometry.point.Point at 0x248a7ab8430>,
#  <shapely.geometry.point.Point at 0x248a7ab8460>,
#  <shapely.geometry.point.Point at 0x248a7ab8490>,
#  <shapely.geometry.point.Point at 0x248a7ab84c0>,
#  <shapely.geometry.point.Point at 0x248a7ab84f0>,
#  <shapely.geometry.point.Point at 0x248a7ab8520>,
#  <shapely.geometry.point.Point at 0x248a7ab8550>,
#  <shapely.geometry.point.Point at 0x248a7ab8580>,
#  <shapely.geometry.point.Point at 0x248a7ab85b0>,
#  <shapely.geometry.point.Point at 0x248a7ab85e0>,
#  <shapely.geometry.point.Point at 0x248a7ab8610>,
#  <shapely.geometry.point.Point at 0x248a7ab8640>,
#  <shapely.geometry.point.Point at 0x248a7ab8670>,
#  <shapely.geometry.point.Point at 0x248a7ab86a0>,
#  <shapely.geometry.point.Point at 0x248a7ab86d0>,
#  <shapely.geometry.point.Point at 0x248a7ab8700>,
#  <shapely.geometry.point.Point at 0x248a7ab8730>,
#  <shapely.geometry.point.Point at 0x248a7ab8760>,
#  <shapely.geometry.point.Point at 0x248a7ab8790>,
#  <shapely.geometry.point.Point at 0x248a7ab87c0>,
#  <shapely.geometry.point.Point at 0x248a7ab87f0>,
#  <shapely.geometry.point.Point at 0x248a7ab8820>,
#  <shapely.geometry.point.Point at 0x248a7ab8850>,
#  <shapely.geometry.point.Point at 0x248a7ab8880>,
#  <shapely.geometry.point.Point at 0x248a7ab88b0>,
#  <shapely.geometry.point.Point at 0x248a7ab88e0>,
#  <shapely.geometry.point.Point at 0x248a7ab8910>,
#  <shapely.geometry.point.Point at 0x248a7ab8940>,
#  <shapely.geometry.point.Point at 0x248a7ab8970>,
#  <shapely.geometry.point.Point at 0x248a7ab89a0>,
#  <shapely.geometry.point.Point at 0x248a7ab89d0>,
#  <shapely.geometry.point.Point at 0x248a7ab8a00>,
#  <shapely.geometry.point.Point at 0x248a7ab8a30>,
#  <shapely.geometry.point.Point at 0x248a7ab8a60>,
#  <shapely.geometry.point.Point at 0x248a7ab8a90>,
#  <shapely.geometry.point.Point at 0x248a7ab8ac0>,
#  <shapely.geometry.point.Point at 0x248a7ab8af0>,
#  <shapely.geometry.point.Point at 0x248a7ab8b20>,
#  <shapely.geometry.point.Point at 0x248a7ab8b50>,
#  <shapely.geometry.point.Point at 0x248a7ab8b80>,
#  <shapely.geometry.point.Point at 0x248a7ab8bb0>,
#  <shapely.geometry.point.Point at 0x248a7ab8be0>,
#  <shapely.geometry.point.Point at 0x248a7ab8c10>,
#  <shapely.geometry.point.Point at 0x248a7ab8c40>,
#  <shapely.geometry.point.Point at 0x248a7ab8c70>,
#  <shapely.geometry.point.Point at 0x248a7ab8ca0>,
#  <shapely.geometry.point.Point at 0x248a7ab8cd0>,
#  <shapely.geometry.point.Point at 0x248a7ab8d00>,
#  <shapely.geometry.point.Point at 0x248a7ab8d30>,
#  <shapely.geometry.point.Point at 0x248a7ab8d60>,
#  <shapely.geometry.point.Point at 0x248a7ab8d90>,
#  <shapely.geometry.point.Point at 0x248a7ab8dc0>,
#  <shapely.geometry.point.Point at 0x248a7ab8df0>,
#  <shapely.geometry.point.Point at 0x248a7ab8e20>,
#  <shapely.geometry.point.Point at 0x248a7ab8e50>,
#  <shapely.geometry.point.Point at 0x248a7ab8e80>,
#  <shapely.geometry.point.Point at 0x248a7ab8eb0>,
#  <shapely.geometry.point.Point at 0x248a7ab8ee0>,
#  <shapely.geometry.point.Point at 0x248a7ab8f10>,
#  <shapely.geometry.point.Point at 0x248a7ab8f40>,
#  <shapely.geometry.point.Point at 0x248a7ab8f70>,
#  <shapely.geometry.point.Point at 0x248a7ab8fa0>,
#  <shapely.geometry.point.Point at 0x248a7ab8fd0>,
#  <shapely.geometry.point.Point at 0x248a7a8e040>,
#  <shapely.geometry.point.Point at 0x248a7a8e070>,
#  <shapely.geometry.point.Point at 0x248a7a8e0a0>,
#  <shapely.geometry.point.Point at 0x248a7a8e0d0>,
#  <shapely.geometry.point.Point at 0x248a7a8e100>,
#  <shapely.geometry.point.Point at 0x248a7a8e130>,
#  <shapely.geometry.point.Point at 0x248a7a8e160>,
#  <shapely.geometry.point.Point at 0x248a7a8e190>,
#  <shapely.geometry.point.Point at 0x248a7a8e1c0>,
#  <shapely.geometry.point.Point at 0x248a7a8e1f0>,
#  <shapely.geometry.point.Point at 0x248a7a8e220>,
#  <shapely.geometry.point.Point at 0x248a7a8e250>,
#  <shapely.geometry.point.Point at 0x248a7a8e280>,
#  <shapely.geometry.point.Point at 0x248a7a8e2b0>,
#  <shapely.geometry.point.Point at 0x248a7a8e2e0>,
#  <shapely.geometry.point.Point at 0x248a7a8e310>,
#  <shapely.geometry.point.Point at 0x248a7a8e340>,
#  <shapely.geometry.point.Point at 0x248a7a8e370>,
#  <shapely.geometry.point.Point at 0x248a7a8e3a0>,
#  <shapely.geometry.point.Point at 0x248a7a8e3d0>,
#  <shapely.geometry.point.Point at 0x248a7a8e400>,
#  <shapely.geometry.point.Point at 0x248a7a8e430>,
#  <shapely.geometry.point.Point at 0x248a7a8e460>,
#  <shapely.geometry.point.Point at 0x248a7a8e490>,
#  <shapely.geometry.point.Point at 0x248a7a8e4c0>,
#  <shapely.geometry.point.Point at 0x248a7a8e4f0>,
#  <shapely.geometry.point.Point at 0x248a7a8e520>,
#  <shapely.geometry.point.Point at 0x248a7a8e550>,
#  <shapely.geometry.point.Point at 0x248a7a8e580>,
#  <shapely.geometry.point.Point at 0x248a7a8e5b0>,
#  <shapely.geometry.point.Point at 0x248a7a8e5e0>,
#  <shapely.geometry.point.Point at 0x248a7a8e610>,
#  <shapely.geometry.point.Point at 0x248a7a8e640>,
#  <shapely.geometry.point.Point at 0x248a7a8e670>,
#  <shapely.geometry.point.Point at 0x248a7a8e6a0>,
#  <shapely.geometry.point.Point at 0x248a7a8e6d0>,
#  <shapely.geometry.point.Point at 0x248a7a8e700>,
#  <shapely.geometry.point.Point at 0x248a7a8e730>,
#  <shapely.geometry.point.Point at 0x248a7a8e760>,
#  <shapely.geometry.point.Point at 0x248a7a8e790>,
#  <shapely.geometry.point.Point at 0x248a7a8e7c0>,
#  <shapely.geometry.point.Point at 0x248a7a8e7f0>,
#  <shapely.geometry.point.Point at 0x248a7a8e820>,
#  <shapely.geometry.point.Point at 0x248a7a8e850>,
#  <shapely.geometry.point.Point at 0x248a7a8e880>,
#  <shapely.geometry.point.Point at 0x248a7a8e8b0>,
#  <shapely.geometry.point.Point at 0x248a7a8e8e0>,
#  <shapely.geometry.point.Point at 0x248a7a8e910>,
#  <shapely.geometry.point.Point at 0x248a7a8e940>,
#  <shapely.geometry.point.Point at 0x248a7a8e970>,
#  <shapely.geometry.point.Point at 0x248a7a8e9a0>,
#  <shapely.geometry.point.Point at 0x248a7a8e9d0>,
#  <shapely.geometry.point.Point at 0x248a7a8ea00>,
#  <shapely.geometry.point.Point at 0x248a7a8ea30>,
#  <shapely.geometry.point.Point at 0x248a7a8ea60>,
#  <shapely.geometry.point.Point at 0x248a7a8ea90>,
#  <shapely.geometry.point.Point at 0x248a7a8eac0>,
#  <shapely.geometry.point.Point at 0x248a7a8eaf0>,
#  <shapely.geometry.point.Point at 0x248a7a8eb20>,
#  <shapely.geometry.point.Point at 0x248a7a8eb50>,
#  <shapely.geometry.point.Point at 0x248a7a8eb80>,
#  <shapely.geometry.point.Point at 0x248a7a8ebb0>,
#  <shapely.geometry.point.Point at 0x248a7a8ebe0>,
#  <shapely.geometry.point.Point at 0x248a7a8ec10>,
#  <shapely.geometry.point.Point at 0x248a7a8ec40>,
#  <shapely.geometry.point.Point at 0x248a7a8ec70>,
#  <shapely.geometry.point.Point at 0x248a7a8eca0>,
#  <shapely.geometry.point.Point at 0x248a7a8ecd0>,
#  <shapely.geometry.point.Point at 0x248a7a8ed00>,
#  <shapely.geometry.point.Point at 0x248a7a8ed30>,
#  <shapely.geometry.point.Point at 0x248a7a8ed60>,
#  <shapely.geometry.point.Point at 0x248a7a8ed90>,
#  <shapely.geometry.point.Point at 0x248a7a8edc0>,
#  <shapely.geometry.point.Point at 0x248a7a8edf0>,
#  <shapely.geometry.point.Point at 0x248a7a8ee20>,
#  <shapely.geometry.point.Point at 0x248a7a8ee50>,
#  <shapely.geometry.point.Point at 0x248a7a8ee80>,
#  <shapely.geometry.point.Point at 0x248a7a8eeb0>,
#  <shapely.geometry.point.Point at 0x248a7a8eee0>,
#  <shapely.geometry.point.Point at 0x248a7a8ef10>,
#  <shapely.geometry.point.Point at 0x248a7a8ef40>,
#  <shapely.geometry.point.Point at 0x248a7a8ef70>,
#  <shapely.geometry.point.Point at 0x248a7a8efa0>,
#  <shapely.geometry.point.Point at 0x248a7a8efd0>,
#  <shapely.geometry.point.Point at 0x248a7a8c040>,
#  <shapely.geometry.point.Point at 0x248a7a8c070>,
#  <shapely.geometry.point.Point at 0x248a7a8c0d0>,
#  <shapely.geometry.point.Point at 0x248a7a8c100>,
#  <shapely.geometry.point.Point at 0x248a7a8c130>,
#  <shapely.geometry.point.Point at 0x248a7a8c160>,
#  <shapely.geometry.point.Point at 0x248a7a8c190>,
#  <shapely.geometry.point.Point at 0x248a7a8c1c0>,
#  <shapely.geometry.point.Point at 0x248a7a8c1f0>,
#  <shapely.geometry.point.Point at 0x248a7a8c220>,
#  <shapely.geometry.point.Point at 0x248a7a8c250>,
#  <shapely.geometry.point.Point at 0x248a7a8c280>,
#  <shapely.geometry.point.Point at 0x248a7a8c2b0>,
#  <shapely.geometry.point.Point at 0x248a7a8c2e0>,
#  <shapely.geometry.point.Point at 0x248a7a8c310>,
#  <shapely.geometry.point.Point at 0x248a7a8c340>,
#  <shapely.geometry.point.Point at 0x248a7a8c370>,
#  <shapely.geometry.point.Point at 0x248a7a8c0a0>,
#  <shapely.geometry.point.Point at 0x248a7a8c3a0>,
#  <shapely.geometry.point.Point at 0x248a7a8c3d0>,
#  <shapely.geometry.point.Point at 0x248a7a8c400>,
#  <shapely.geometry.point.Point at 0x248a7a8c430>,
#  <shapely.geometry.point.Point at 0x248a7a8c460>,
#  <shapely.geometry.point.Point at 0x248a7a8c490>,
#  <shapely.geometry.point.Point at 0x248a7a8c4c0>,
#  <shapely.geometry.point.Point at 0x248a7a8c4f0>,
#  <shapely.geometry.point.Point at 0x248a7a8c520>,
#  <shapely.geometry.point.Point at 0x248a7a8c550>,
#  <shapely.geometry.point.Point at 0x248a7a8c580>,
#  <shapely.geometry.point.Point at 0x248a7a8c5b0>,
#  <shapely.geometry.point.Point at 0x248a7a8c5e0>,
#  <shapely.geometry.point.Point at 0x248a7a8c610>,
#  <shapely.geometry.point.Point at 0x248a7a8c670>,
#  <shapely.geometry.point.Point at 0x248a7a8c6a0>,
#  <shapely.geometry.point.Point at 0x248a7a8c6d0>,
#  <shapely.geometry.point.Point at 0x248a7a8c700>,
#  <shapely.geometry.point.Point at 0x248a7a8c730>,
#  <shapely.geometry.point.Point at 0x248a7a8c760>,
#  <shapely.geometry.point.Point at 0x248a7a8c790>,
#  <shapely.geometry.point.Point at 0x248a7a8c7c0>,
#  <shapely.geometry.point.Point at 0x248a7a8c7f0>,
#  <shapely.geometry.point.Point at 0x248a7a8c820>,
#  <shapely.geometry.point.Point at 0x248a7a8c850>,
#  <shapely.geometry.point.Point at 0x248a7a8c880>,
#  <shapely.geometry.point.Point at 0x248a7a8c8b0>,
#  <shapely.geometry.point.Point at 0x248a7a8c8e0>,
#  <shapely.geometry.point.Point at 0x248a7a8c910>,
#  <shapely.geometry.point.Point at 0x248a7a8c640>,
#  <shapely.geometry.point.Point at 0x248a7a8c940>,
#  <shapely.geometry.point.Point at 0x248a7a8c970>,
#  <shapely.geometry.point.Point at 0x248a7a8c9a0>,
#  <shapely.geometry.point.Point at 0x248a7a8c9d0>,
#  <shapely.geometry.point.Point at 0x248a7a8ca00>,
#  <shapely.geometry.point.Point at 0x248a7a8ca30>,
#  <shapely.geometry.point.Point at 0x248a7a8ca60>,
#  <shapely.geometry.point.Point at 0x248a7a8ca90>,
#  <shapely.geometry.point.Point at 0x248a7a8cac0>,
#  <shapely.geometry.point.Point at 0x248a7a8caf0>,
#  <shapely.geometry.point.Point at 0x248a7a8cb20>,
#  <shapely.geometry.point.Point at 0x248a7a8cb50>,
#  <shapely.geometry.point.Point at 0x248a7a8cb80>,
#  <shapely.geometry.point.Point at 0x248a7a8cbb0>,
#  <shapely.geometry.point.Point at 0x248a7a8cc10>,
#  <shapely.geometry.point.Point at 0x248a7a8cc40>,
#  <shapely.geometry.point.Point at 0x248a7a8cc70>,
#  <shapely.geometry.point.Point at 0x248a7a8cca0>,
#  <shapely.geometry.point.Point at 0x248a7a8ccd0>,
#  <shapely.geometry.point.Point at 0x248a7a8cd00>,
#  <shapely.geometry.point.Point at 0x248a7a8cd30>,
#  <shapely.geometry.point.Point at 0x248a7a8cd60>,
#  <shapely.geometry.point.Point at 0x248a7a8cd90>,
#  <shapely.geometry.point.Point at 0x248a7a8cdc0>,
#  <shapely.geometry.point.Point at 0x248a7a8cdf0>,
#  <shapely.geometry.point.Point at 0x248a7a8ce20>,
#  <shapely.geometry.point.Point at 0x248a7a8ce50>,
#  <shapely.geometry.point.Point at 0x248a7a8ce80>,
#  <shapely.geometry.point.Point at 0x248a7a8ceb0>,
#  <shapely.geometry.point.Point at 0x248a7a8cbe0>,
#  <shapely.geometry.point.Point at 0x248a7a8cee0>,
#  <shapely.geometry.point.Point at 0x248a7a8cf10>,
#  <shapely.geometry.point.Point at 0x248a7a8cf40>,
#  <shapely.geometry.point.Point at 0x248a7a8cf70>,
#  <shapely.geometry.point.Point at 0x248a7a8cfa0>,
#  <shapely.geometry.point.Point at 0x248a7a8cfd0>,
#  <shapely.geometry.point.Point at 0x2492e5f4040>,
#  <shapely.geometry.point.Point at 0x2492e5f4070>,
#  <shapely.geometry.point.Point at 0x2492e5f40a0>,
#  <shapely.geometry.point.Point at 0x2492e5f40d0>,
#  <shapely.geometry.point.Point at 0x2492e5f4100>,
#  <shapely.geometry.point.Point at 0x2492e5f4130>,
#  <shapely.geometry.point.Point at 0x2492e5f4160>,
#  <shapely.geometry.point.Point at 0x2492e5f4190>,
#  <shapely.geometry.point.Point at 0x2492e5f41f0>,
#  <shapely.geometry.point.Point at 0x2492e5f4220>,
#  <shapely.geometry.point.Point at 0x2492e5f4250>,
#  <shapely.geometry.point.Point at 0x2492e5f4280>,
#  <shapely.geometry.point.Point at 0x2492e5f42b0>,
#  <shapely.geometry.point.Point at 0x2492e5f42e0>,
#  <shapely.geometry.point.Point at 0x2492e5f4310>,
#  <shapely.geometry.point.Point at 0x2492e5f4340>,
#  <shapely.geometry.point.Point at 0x2492e5f4370>,
#  <shapely.geometry.point.Point at 0x2492e5f43a0>,
#  <shapely.geometry.point.Point at 0x2492e5f43d0>,
#  <shapely.geometry.point.Point at 0x2492e5f4400>,
#  <shapely.geometry.point.Point at 0x2492e5f4430>,
#  <shapely.geometry.point.Point at 0x2492e5f4460>,
#  <shapely.geometry.point.Point at 0x2492e5f4490>,
#  <shapely.geometry.point.Point at 0x2492e5f41c0>,
#  <shapely.geometry.point.Point at 0x2492e5f44c0>,
#  <shapely.geometry.point.Point at 0x2492e5f44f0>,
#  <shapely.geometry.point.Point at 0x2492e5f4520>,
#  <shapely.geometry.point.Point at 0x2492e5f4550>,
#  <shapely.geometry.point.Point at 0x2492e5f4580>,
#  <shapely.geometry.point.Point at 0x2492e5f45b0>,
#  <shapely.geometry.point.Point at 0x2492e5f45e0>,
#  <shapely.geometry.point.Point at 0x2492e5f4610>,
#  <shapely.geometry.point.Point at 0x2492e5f4640>,
#  <shapely.geometry.point.Point at 0x2492e5f4670>,
#  <shapely.geometry.point.Point at 0x2492e5f46a0>,
#  <shapely.geometry.point.Point at 0x2492e5f46d0>,
#  <shapely.geometry.point.Point at 0x2492e5f4700>,
#  <shapely.geometry.point.Point at 0x2492e5f4730>,
#  <shapely.geometry.point.Point at 0x2492e5f4760>,
#  <shapely.geometry.point.Point at 0x2492e5f47c0>,
#  <shapely.geometry.point.Point at 0x2492e5f4790>,
#  <shapely.geometry.point.Point at 0x2492e5f47f0>,
#  <shapely.geometry.point.Point at 0x2492e5f4820>,
#  <shapely.geometry.point.Point at 0x2492e5f4850>,
#  <shapely.geometry.point.Point at 0x2492e5f4880>,
#  <shapely.geometry.point.Point at 0x2492e5f48b0>,
#  <shapely.geometry.point.Point at 0x2492e5f48e0>,
#  <shapely.geometry.point.Point at 0x2492e5f4910>,
#  <shapely.geometry.point.Point at 0x2492e5f4940>,
#  <shapely.geometry.point.Point at 0x2492e5f4970>,
#  <shapely.geometry.point.Point at 0x2492e5f49a0>,
#  <shapely.geometry.point.Point at 0x2492e5f49d0>,
#  <shapely.geometry.point.Point at 0x2492e5f4a00>,
#  <shapely.geometry.point.Point at 0x2492e5f4a30>,
#  <shapely.geometry.point.Point at 0x2492e5f4a60>,
#  <shapely.geometry.point.Point at 0x2492e5f4a90>,
#  <shapely.geometry.point.Point at 0x2492e5f4ac0>,
#  <shapely.geometry.point.Point at 0x2492e5f4af0>,
#  <shapely.geometry.point.Point at 0x2492e5f4b20>,
#  <shapely.geometry.point.Point at 0x2492e5f4b50>,
#  <shapely.geometry.point.Point at 0x2492e5f4b80>,
#  <shapely.geometry.point.Point at 0x2492e5f4bb0>,
#  <shapely.geometry.point.Point at 0x2492e5f4be0>,
#  <shapely.geometry.point.Point at 0x2492e5f4c10>,
#  <shapely.geometry.point.Point at 0x2492e5f4c40>,
#  <shapely.geometry.point.Point at 0x2492e5f4c70>,
#  <shapely.geometry.point.Point at 0x2492e5f4ca0>,
#  <shapely.geometry.point.Point at 0x2492e5f4cd0>,
#  <shapely.geometry.point.Point at 0x2492e5f4d00>,
#  <shapely.geometry.point.Point at 0x2492e5f4d30>,
#  <shapely.geometry.point.Point at 0x2492e5f4d60>,
#  <shapely.geometry.point.Point at 0x2492e5f4d90>,
#  <shapely.geometry.point.Point at 0x2492e5f4dc0>,
#  <shapely.geometry.point.Point at 0x2492e5f4df0>,
#  <shapely.geometry.point.Point at 0x2492e5f4e20>,
#  <shapely.geometry.point.Point at 0x2492e5f4e50>,
#  <shapely.geometry.point.Point at 0x2492e5f4e80>,
#  <shapely.geometry.point.Point at 0x2492e5f4eb0>,
#  <shapely.geometry.point.Point at 0x2492e5f4ee0>,
#  <shapely.geometry.point.Point at 0x2492e5f4f10>,
#  <shapely.geometry.point.Point at 0x2492e5f4f40>,
#  <shapely.geometry.point.Point at 0x2492e5f4f70>,
#  <shapely.geometry.point.Point at 0x2492e5f4fa0>,
#  <shapely.geometry.point.Point at 0x2492e5f4fd0>,
#  <shapely.geometry.point.Point at 0x2492e5fa040>,
#  <shapely.geometry.point.Point at 0x2492e5fa070>,
#  <shapely.geometry.point.Point at 0x2492e5fa0a0>,
#  <shapely.geometry.point.Point at 0x2492e5fa0d0>,
#  <shapely.geometry.point.Point at 0x2492e5fa100>,
#  <shapely.geometry.point.Point at 0x2492e5fa130>,
#  <shapely.geometry.point.Point at 0x2492e5fa160>,
#  <shapely.geometry.point.Point at 0x2492e5fa190>,
#  <shapely.geometry.point.Point at 0x2492e5fa1c0>,
#  <shapely.geometry.point.Point at 0x2492e5fa1f0>,
#  <shapely.geometry.point.Point at 0x2492e5fa220>,
#  <shapely.geometry.point.Point at 0x2492e5fa250>,
#  <shapely.geometry.point.Point at 0x2492e5fa280>,
#  <shapely.geometry.point.Point at 0x2492e5fa2b0>,
#  <shapely.geometry.point.Point at 0x2492e5fa2e0>,
#  <shapely.geometry.point.Point at 0x2492e5fa310>,
#  <shapely.geometry.point.Point at 0x2492e5fa340>,
#  <shapely.geometry.point.Point at 0x2492e5fa370>,
#  <shapely.geometry.point.Point at 0x2492e5fa3a0>,
#  <shapely.geometry.point.Point at 0x2492e5fa3d0>,
#  <shapely.geometry.point.Point at 0x2492e5fa400>,
#  <shapely.geometry.point.Point at 0x2492e5fa430>,
#  <shapely.geometry.point.Point at 0x2492e5fa460>,
#  <shapely.geometry.point.Point at 0x2492e5fa490>,
#  <shapely.geometry.point.Point at 0x2492e5fa4c0>,
#  <shapely.geometry.point.Point at 0x2492e5fa4f0>,
#  <shapely.geometry.point.Point at 0x2492e5fa520>,
#  <shapely.geometry.point.Point at 0x2492e5fa550>,
#  <shapely.geometry.point.Point at 0x2492e5fa580>,
#  <shapely.geometry.point.Point at 0x2492e5fa5b0>,
#  <shapely.geometry.point.Point at 0x2492e5fa5e0>,
#  <shapely.geometry.point.Point at 0x2492e5fa610>,
#  <shapely.geometry.point.Point at 0x2492e5fa640>,
#  <shapely.geometry.point.Point at 0x2492e5fa670>,
#  <shapely.geometry.point.Point at 0x2492e5fa6a0>,
#  <shapely.geometry.point.Point at 0x2492e5fa6d0>,
#  <shapely.geometry.point.Point at 0x2492e5fa700>,
#  <shapely.geometry.point.Point at 0x2492e5fa730>,
#  <shapely.geometry.point.Point at 0x2492e5fa760>,
#  <shapely.geometry.point.Point at 0x2492e5fa790>,
#  <shapely.geometry.point.Point at 0x2492e5fa7c0>,
#  <shapely.geometry.point.Point at 0x2492e5fa7f0>,
#  <shapely.geometry.point.Point at 0x2492e5fa820>,
#  <shapely.geometry.point.Point at 0x2492e5fa850>,
#  <shapely.geometry.point.Point at 0x2492e5fa880>,
#  <shapely.geometry.point.Point at 0x2492e5fa8b0>,
#  <shapely.geometry.point.Point at 0x2492e5fa8e0>,
#  <shapely.geometry.point.Point at 0x2492e5fa910>,
#  <shapely.geometry.point.Point at 0x2492e5fa940>,
#  <shapely.geometry.point.Point at 0x2492e5fa970>,
#  <shapely.geometry.point.Point at 0x2492e5fa9a0>,
#  <shapely.geometry.point.Point at 0x2492e5fa9d0>,
#  <shapely.geometry.point.Point at 0x2492e5faa00>,
#  <shapely.geometry.point.Point at 0x2492e5faa30>,
#  <shapely.geometry.point.Point at 0x2492e5faa60>,
#  <shapely.geometry.point.Point at 0x2492e5faa90>,
#  <shapely.geometry.point.Point at 0x2492e5faac0>,
#  <shapely.geometry.point.Point at 0x2492e5faaf0>,
#  <shapely.geometry.point.Point at 0x2492e5fab20>,
#  <shapely.geometry.point.Point at 0x2492e5fab50>,
#  <shapely.geometry.point.Point at 0x2492e5fab80>,
#  <shapely.geometry.point.Point at 0x2492e5fabb0>,
#  <shapely.geometry.point.Point at 0x2492e5fabe0>,
#  <shapely.geometry.point.Point at 0x2492e5fac10>,
#  <shapely.geometry.point.Point at 0x2492e5fac40>,
#  <shapely.geometry.point.Point at 0x2492e5fac70>,
#  <shapely.geometry.point.Point at 0x2492e5faca0>,
#  <shapely.geometry.point.Point at 0x2492e5facd0>,
#  <shapely.geometry.point.Point at 0x2492e5fad00>,
#  <shapely.geometry.point.Point at 0x2492e5fad30>,
#  <shapely.geometry.point.Point at 0x2492e5fad60>,
#  <shapely.geometry.point.Point at 0x2492e5fad90>,
#  <shapely.geometry.point.Point at 0x2492e5fadc0>,
#  <shapely.geometry.point.Point at 0x2492e5fadf0>,
#  <shapely.geometry.point.Point at 0x2492e5fae20>,
#  <shapely.geometry.point.Point at 0x2492e5fae50>,
#  <shapely.geometry.point.Point at 0x2492e5fae80>,
#  <shapely.geometry.point.Point at 0x2492e5faeb0>,
#  <shapely.geometry.point.Point at 0x2492e5faee0>,
#  <shapely.geometry.point.Point at 0x2492e5faf10>,
#  <shapely.geometry.point.Point at 0x2492e5faf40>,
#  <shapely.geometry.point.Point at 0x2492e5faf70>,
#  <shapely.geometry.point.Point at 0x2492e5fafa0>,
#  <shapely.geometry.point.Point at 0x2492e5fafd0>,
#  <shapely.geometry.point.Point at 0x2492e618040>,
#  <shapely.geometry.point.Point at 0x2492e618070>,
#  <shapely.geometry.point.Point at 0x2492e6180a0>,
#  <shapely.geometry.point.Point at 0x2492e6180d0>,
#  <shapely.geometry.point.Point at 0x2492e618100>,
#  <shapely.geometry.point.Point at 0x2492e618130>,
#  <shapely.geometry.point.Point at 0x2492e618160>,
#  <shapely.geometry.point.Point at 0x2492e618190>,
#  <shapely.geometry.point.Point at 0x2492e6181c0>,
#  <shapely.geometry.point.Point at 0x2492e6181f0>,
#  <shapely.geometry.point.Point at 0x2492e618220>,
#  <shapely.geometry.point.Point at 0x2492e618250>,
#  <shapely.geometry.point.Point at 0x2492e618280>,
#  <shapely.geometry.point.Point at 0x2492e6182b0>,
#  <shapely.geometry.point.Point at 0x2492e6182e0>,
#  <shapely.geometry.point.Point at 0x2492e618310>,
#  <shapely.geometry.point.Point at 0x2492e618340>,
#  <shapely.geometry.point.Point at 0x2492e618370>,
#  <shapely.geometry.point.Point at 0x2492e6183a0>,
#  <shapely.geometry.point.Point at 0x2492e6183d0>,
#  <shapely.geometry.point.Point at 0x2492e618400>,
#  <shapely.geometry.point.Point at 0x2492e618430>,
#  <shapely.geometry.point.Point at 0x2492e618460>,
#  <shapely.geometry.point.Point at 0x2492e618490>,
#  <shapely.geometry.point.Point at 0x2492e6184c0>,
#  <shapely.geometry.point.Point at 0x2492e6184f0>,
#  <shapely.geometry.point.Point at 0x2492e618520>,
#  <shapely.geometry.point.Point at 0x2492e618550>,
#  <shapely.geometry.point.Point at 0x2492e618580>,
#  <shapely.geometry.point.Point at 0x2492e6185b0>,
#  <shapely.geometry.point.Point at 0x2492e6185e0>,
#  <shapely.geometry.point.Point at 0x2492e618610>,
#  <shapely.geometry.point.Point at 0x2492e618640>,
#  <shapely.geometry.point.Point at 0x2492e618670>,
#  <shapely.geometry.point.Point at 0x2492e6186a0>,
#  <shapely.geometry.point.Point at 0x2492e6186d0>,
#  <shapely.geometry.point.Point at 0x2492e618700>,
#  <shapely.geometry.point.Point at 0x2492e618730>,
#  <shapely.geometry.point.Point at 0x2492e618760>,
#  <shapely.geometry.point.Point at 0x2492e618790>,
#  <shapely.geometry.point.Point at 0x2492e6187c0>,
#  <shapely.geometry.point.Point at 0x2492e6187f0>,
#  <shapely.geometry.point.Point at 0x2492e618820>,
#  <shapely.geometry.point.Point at 0x2492e618850>,
#  <shapely.geometry.point.Point at 0x2492e618880>,
#  <shapely.geometry.point.Point at 0x2492e6188b0>,
#  <shapely.geometry.point.Point at 0x2492e6188e0>,
#  <shapely.geometry.point.Point at 0x2492e618910>,
#  <shapely.geometry.point.Point at 0x2492e618940>,
#  <shapely.geometry.point.Point at 0x2492e618970>,
#  <shapely.geometry.point.Point at 0x2492e6189a0>,
#  <shapely.geometry.point.Point at 0x2492e6189d0>,
#  <shapely.geometry.point.Point at 0x2492e618a30>,
#  <shapely.geometry.point.Point at 0x2492e618a60>,
#  <shapely.geometry.point.Point at 0x2492e618a90>,
#  <shapely.geometry.point.Point at 0x2492e618ac0>,
#  <shapely.geometry.point.Point at 0x2492e618af0>,
#  <shapely.geometry.point.Point at 0x2492e618b20>,
#  <shapely.geometry.point.Point at 0x2492e618b50>,
#  <shapely.geometry.point.Point at 0x2492e618b80>,
#  <shapely.geometry.point.Point at 0x2492e618bb0>,
#  <shapely.geometry.point.Point at 0x2492e618a00>,
#  <shapely.geometry.point.Point at 0x2492e618be0>,
#  <shapely.geometry.point.Point at 0x2492e618c10>,
#  <shapely.geometry.point.Point at 0x2492e618c40>,
#  <shapely.geometry.point.Point at 0x2492e618c70>,
#  <shapely.geometry.point.Point at 0x2492e618ca0>,
#  <shapely.geometry.point.Point at 0x2492e618cd0>,
#  <shapely.geometry.point.Point at 0x2492e618d00>,
#  <shapely.geometry.point.Point at 0x2492e618d30>,
#  <shapely.geometry.point.Point at 0x2492e618d60>,
#  <shapely.geometry.point.Point at 0x2492e618d90>,
#  <shapely.geometry.point.Point at 0x2492e618dc0>,
#  <shapely.geometry.point.Point at 0x2492e618df0>,
#  <shapely.geometry.point.Point at 0x2492e618e20>,
#  <shapely.geometry.point.Point at 0x2492e618e50>,
#  <shapely.geometry.point.Point at 0x2492e618e80>,
#  <shapely.geometry.point.Point at 0x2492e618eb0>,
#  <shapely.geometry.point.Point at 0x2492e618ee0>,
#  <shapely.geometry.point.Point at 0x2492e618f10>,
#  <shapely.geometry.point.Point at 0x2492e618f70>,
#  <shapely.geometry.point.Point at 0x2492e618fa0>,
#  <shapely.geometry.point.Point at 0x2492e618fd0>,
#  <shapely.geometry.point.Point at 0x2492e618f40>,
#  <shapely.geometry.point.Point at 0x2492e61f040>,
#  <shapely.geometry.point.Point at 0x2492e61f070>,
#  <shapely.geometry.point.Point at 0x2492e61f0a0>,
#  <shapely.geometry.point.Point at 0x2492e61f0d0>,
#  <shapely.geometry.point.Point at 0x2492e61f100>,
#  <shapely.geometry.point.Point at 0x2492e61f130>,
#  <shapely.geometry.point.Point at 0x2492e61f160>,
#  <shapely.geometry.point.Point at 0x2492e61f190>,
#  <shapely.geometry.point.Point at 0x2492e61f1c0>,
#  <shapely.geometry.point.Point at 0x2492e61f1f0>,
#  <shapely.geometry.point.Point at 0x2492e61f220>,
#  <shapely.geometry.point.Point at 0x2492e61f250>,
#  <shapely.geometry.point.Point at 0x2492e61f280>,
#  <shapely.geometry.point.Point at 0x2492e61f2b0>,
#  <shapely.geometry.point.Point at 0x2492e61f2e0>,
#  <shapely.geometry.point.Point at 0x2492e61f310>,
#  <shapely.geometry.point.Point at 0x2492e61f340>,
#  <shapely.geometry.point.Point at 0x2492e61f370>,
#  <shapely.geometry.point.Point at 0x2492e61f3a0>,
#  <shapely.geometry.point.Point at 0x2492e61f3d0>,
#  <shapely.geometry.point.Point at 0x2492e61f400>,
#  <shapely.geometry.point.Point at 0x2492e61f430>,
#  <shapely.geometry.point.Point at 0x2492e61f460>,
#  <shapely.geometry.point.Point at 0x2492e61f490>,
#  <shapely.geometry.point.Point at 0x2492e61f4c0>,
#  <shapely.geometry.point.Point at 0x2492e61f4f0>,
#  <shapely.geometry.point.Point at 0x2492e61f520>,
#  <shapely.geometry.point.Point at 0x2492e61f550>,
#  <shapely.geometry.point.Point at 0x2492e61f580>,
#  <shapely.geometry.point.Point at 0x2492e61f5b0>,
#  <shapely.geometry.point.Point at 0x2492e61f5e0>,
#  <shapely.geometry.point.Point at 0x2492e61f610>,
#  <shapely.geometry.point.Point at 0x2492e61f640>,
#  <shapely.geometry.point.Point at 0x2492e61f670>,
#  <shapely.geometry.point.Point at 0x2492e61f6a0>,
#  <shapely.geometry.point.Point at 0x2492e61f6d0>,
#  <shapely.geometry.point.Point at 0x2492e61f700>,
#  <shapely.geometry.point.Point at 0x2492e61f730>,
#  <shapely.geometry.point.Point at 0x2492e61f760>,
#  <shapely.geometry.point.Point at 0x2492e61f790>,
#  <shapely.geometry.point.Point at 0x2492e61f7c0>,
#  <shapely.geometry.point.Point at 0x2492e61f7f0>,
#  <shapely.geometry.point.Point at 0x2492e61f820>,
#  <shapely.geometry.point.Point at 0x2492e61f850>,
#  <shapely.geometry.point.Point at 0x2492e61f880>,
#  <shapely.geometry.point.Point at 0x2492e61f8b0>,
#  <shapely.geometry.point.Point at 0x2492e61f8e0>,
#  <shapely.geometry.point.Point at 0x2492e61f910>,
#  <shapely.geometry.point.Point at 0x2492e61f940>,
#  <shapely.geometry.point.Point at 0x2492e61f970>,
#  <shapely.geometry.point.Point at 0x2492e61f9a0>,
#  <shapely.geometry.point.Point at 0x2492e61f9d0>,
#  <shapely.geometry.point.Point at 0x2492e61fa00>,
#  <shapely.geometry.point.Point at 0x2492e61fa30>,
#  <shapely.geometry.point.Point at 0x2492e61fa60>,
#  <shapely.geometry.point.Point at 0x2492e61fa90>,
#  <shapely.geometry.point.Point at 0x2492e61fac0>,
#  <shapely.geometry.point.Point at 0x2492e61faf0>,
#  <shapely.geometry.point.Point at 0x2492e61fb20>,
#  <shapely.geometry.point.Point at 0x2492e61fb50>,
#  <shapely.geometry.point.Point at 0x2492e61fb80>,
#  <shapely.geometry.point.Point at 0x2492e61fbb0>,
#  <shapely.geometry.point.Point at 0x2492e61fbe0>,
#  <shapely.geometry.point.Point at 0x2492e61fc10>,
#  <shapely.geometry.point.Point at 0x2492e61fc40>,
#  <shapely.geometry.point.Point at 0x2492e61fc70>,
#  <shapely.geometry.point.Point at 0x2492e61fca0>,
#  <shapely.geometry.point.Point at 0x2492e61fcd0>,
#  <shapely.geometry.point.Point at 0x2492e61fd00>,
#  <shapely.geometry.point.Point at 0x2492e61fd30>,
#  <shapely.geometry.point.Point at 0x2492e61fd60>,
#  <shapely.geometry.point.Point at 0x2492e61fd90>,
#  <shapely.geometry.point.Point at 0x2492e61fdc0>,
#  <shapely.geometry.point.Point at 0x2492e61fdf0>,
#  <shapely.geometry.point.Point at 0x2492e61fe20>,
#  <shapely.geometry.point.Point at 0x2492e61fe50>,
#  <shapely.geometry.point.Point at 0x2492e61fe80>,
#  <shapely.geometry.point.Point at 0x2492e61feb0>,
#  <shapely.geometry.point.Point at 0x2492e61fee0>,
#  <shapely.geometry.point.Point at 0x2492e61ff10>,
#  <shapely.geometry.point.Point at 0x2492e61ff40>,
#  <shapely.geometry.point.Point at 0x2492e61ff70>,
#  <shapely.geometry.point.Point at 0x2492e61ffa0>,
#  <shapely.geometry.point.Point at 0x2492e61ffd0>,
#  <shapely.geometry.point.Point at 0x2492e61e040>,
#  <shapely.geometry.point.Point at 0x2492e61e070>,
#  <shapely.geometry.point.Point at 0x2492e61e0a0>,
#  <shapely.geometry.point.Point at 0x2492e61e0d0>,
#  <shapely.geometry.point.Point at 0x2492e61e100>,
#  <shapely.geometry.point.Point at 0x2492e61e130>,
#  <shapely.geometry.point.Point at 0x2492e61e160>,
#  <shapely.geometry.point.Point at 0x2492e61e190>,
#  <shapely.geometry.point.Point at 0x2492e61e1c0>,
#  <shapely.geometry.point.Point at 0x2492e61e1f0>,
#  <shapely.geometry.point.Point at 0x2492e61e220>,
#  <shapely.geometry.point.Point at 0x2492e61e250>,
#  <shapely.geometry.point.Point at 0x2492e61e280>,
#  <shapely.geometry.point.Point at 0x2492e61e2e0>,
#  <shapely.geometry.point.Point at 0x2492e61e310>,
#  <shapely.geometry.point.Point at 0x2492e61e340>,
#  <shapely.geometry.point.Point at 0x2492e61e370>,
#  <shapely.geometry.point.Point at 0x2492e61e3a0>,
#  <shapely.geometry.point.Point at 0x2492e61e3d0>,
#  <shapely.geometry.point.Point at 0x2492e61e400>,
#  <shapely.geometry.point.Point at 0x2492e61e430>,
#  <shapely.geometry.point.Point at 0x2492e61e460>,
#  <shapely.geometry.point.Point at 0x2492e61e490>,
#  <shapely.geometry.point.Point at 0x2492e61e4c0>,
#  <shapely.geometry.point.Point at 0x2492e61e4f0>,
#  <shapely.geometry.point.Point at 0x2492e61e520>,
#  <shapely.geometry.point.Point at 0x2492e61e550>,
#  <shapely.geometry.point.Point at 0x2492e61e580>,
#  <shapely.geometry.point.Point at 0x2492e61e5b0>,
#  <shapely.geometry.point.Point at 0x2492e61e5e0>,
#  <shapely.geometry.point.Point at 0x2492e61e2b0>,
#  <shapely.geometry.point.Point at 0x2492e61e610>,
#  <shapely.geometry.point.Point at 0x2492e61e640>,
#  <shapely.geometry.point.Point at 0x2492e61e670>,
#  <shapely.geometry.point.Point at 0x2492e61e6a0>,
#  <shapely.geometry.point.Point at 0x2492e61e6d0>,
#  <shapely.geometry.point.Point at 0x2492e61e700>,
#  <shapely.geometry.point.Point at 0x2492e61e730>,
#  <shapely.geometry.point.Point at 0x2492e61e760>,
#  <shapely.geometry.point.Point at 0x2492e61e790>,
#  <shapely.geometry.point.Point at 0x2492e61e7c0>,
#  <shapely.geometry.point.Point at 0x2492e61e7f0>,
#  <shapely.geometry.point.Point at 0x2492e61e820>,
#  <shapely.geometry.point.Point at 0x2492e61e850>,
#  <shapely.geometry.point.Point at 0x2492e61e8b0>,
#  <shapely.geometry.point.Point at 0x2492e61e880>,
#  <shapely.geometry.point.Point at 0x2492e61e8e0>,
#  <shapely.geometry.point.Point at 0x2492e61e910>,
#  <shapely.geometry.point.Point at 0x2492e61e940>,
#  <shapely.geometry.point.Point at 0x2492e61e970>,
#  <shapely.geometry.point.Point at 0x2492e61e9a0>,
#  <shapely.geometry.point.Point at 0x2492e61e9d0>,
#  <shapely.geometry.point.Point at 0x2492e61ea00>,
#  <shapely.geometry.point.Point at 0x2492e61ea30>,
#  <shapely.geometry.point.Point at 0x2492e61ea60>,
#  <shapely.geometry.point.Point at 0x2492e61ea90>,
#  <shapely.geometry.point.Point at 0x2492e61eac0>,
#  <shapely.geometry.point.Point at 0x2492e61eaf0>,
#  <shapely.geometry.point.Point at 0x2492e61eb20>,
#  <shapely.geometry.point.Point at 0x2492e61eb50>,
#  <shapely.geometry.point.Point at 0x2492e61eb80>,
#  <shapely.geometry.point.Point at 0x2492e61ebb0>,
#  <shapely.geometry.point.Point at 0x2492e61ebe0>,
#  <shapely.geometry.point.Point at 0x2492e61ec10>,
#  <shapely.geometry.point.Point at 0x2492e61ec40>,
#  <shapely.geometry.point.Point at 0x2492e61ec70>,
#  <shapely.geometry.point.Point at 0x2492e61eca0>,
#  <shapely.geometry.point.Point at 0x2492e61ecd0>,
#  <shapely.geometry.point.Point at 0x2492e61ed00>,
#  <shapely.geometry.point.Point at 0x2492e61ed30>,
#  <shapely.geometry.point.Point at 0x2492e61ed60>,
#  <shapely.geometry.point.Point at 0x2492e61ed90>,
#  <shapely.geometry.point.Point at 0x2492e61edc0>,
#  <shapely.geometry.point.Point at 0x2492e61edf0>,
#  <shapely.geometry.point.Point at 0x2492e61ee20>,
#  <shapely.geometry.point.Point at 0x2492e61ee50>,
#  <shapely.geometry.point.Point at 0x2492e61ee80>,
#  <shapely.geometry.point.Point at 0x2492e61eeb0>,
#  <shapely.geometry.point.Point at 0x2492e61eee0>,
#  <shapely.geometry.point.Point at 0x2492e61ef10>,
#  <shapely.geometry.point.Point at 0x2492e61ef40>,
#  <shapely.geometry.point.Point at 0x2492e61ef70>,
#  <shapely.geometry.point.Point at 0x2492e61efa0>,
#  <shapely.geometry.point.Point at 0x2492e61efd0>,
#  <shapely.geometry.point.Point at 0x2492e605040>,
#  <shapely.geometry.point.Point at 0x2492e605070>,
#  <shapely.geometry.point.Point at 0x2492e6050a0>,
#  <shapely.geometry.point.Point at 0x2492e6050d0>,
#  <shapely.geometry.point.Point at 0x2492e605100>,
#  <shapely.geometry.point.Point at 0x2492e605130>,
#  <shapely.geometry.point.Point at 0x2492e605160>,
#  <shapely.geometry.point.Point at 0x2492e605190>,
#  <shapely.geometry.point.Point at 0x2492e6051c0>,
#  <shapely.geometry.point.Point at 0x2492e6051f0>,
#  <shapely.geometry.point.Point at 0x2492e605220>,
#  <shapely.geometry.point.Point at 0x2492e605250>,
#  <shapely.geometry.point.Point at 0x2492e605280>,
#  <shapely.geometry.point.Point at 0x2492e6052b0>,
#  <shapely.geometry.point.Point at 0x2492e6052e0>,
#  <shapely.geometry.point.Point at 0x2492e605310>,
#  <shapely.geometry.point.Point at 0x2492e605340>,
#  <shapely.geometry.point.Point at 0x2492e605370>,
#  <shapely.geometry.point.Point at 0x2492e6053a0>,
#  <shapely.geometry.point.Point at 0x2492e6053d0>,
#  <shapely.geometry.point.Point at 0x2492e605400>,
#  <shapely.geometry.point.Point at 0x2492e605430>,
#  <shapely.geometry.point.Point at 0x2492e605460>,
#  <shapely.geometry.point.Point at 0x2492e605490>,
#  <shapely.geometry.point.Point at 0x2492e6054c0>,
#  <shapely.geometry.point.Point at 0x2492e605520>,
#  <shapely.geometry.point.Point at 0x2492e6054f0>,
#  <shapely.geometry.point.Point at 0x2492e605550>,
#  <shapely.geometry.point.Point at 0x2492e605580>,
#  <shapely.geometry.point.Point at 0x2492e6055b0>,
#  <shapely.geometry.point.Point at 0x2492e6055e0>,
#  <shapely.geometry.point.Point at 0x2492e605610>,
#  <shapely.geometry.point.Point at 0x2492e605640>,
#  <shapely.geometry.point.Point at 0x2492e605670>,
#  <shapely.geometry.point.Point at 0x2492e6056a0>,
#  <shapely.geometry.point.Point at 0x2492e6056d0>,
#  <shapely.geometry.point.Point at 0x2492e605700>,
#  <shapely.geometry.point.Point at 0x2492e605730>,
#  <shapely.geometry.point.Point at 0x2492e605760>,
#  ...]

# %%
points = [(-86.81236, 36.145059),(-86.618303, 36.194334)]

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 491122 entries, 0 to 491121
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Type        491122 non-null  object
#  1   Client ID   491122 non-null  int64
#  2   Time        491122 non-null  object
#  3   Date        491122 non-null  object
#  4   Time Stamp  491122 non-null  object
#  5   LAT         491122 non-null  float64
#  6   LONG        491122 non-null  float64
#  7   geometry    491122 non-null  geometry
# dtypes: float64(2), geometry(1), int64(1), object(4)
# memory usage: 30.0+ MB

# %%
place = 'Nashville, TN, USA'
network_type = 'walk'
trip_times = [5, 10, 15, 20, 25]
travel_speed = 4.5

# %%
# download the street network
G = ox.graph_from_place(place, network_type=network_type)

# %%
import folium

# %%
map = folium.Map((points[0][1],points[0][0]), zoom_start=13)
for pt in points:
    marker = folium.Marker([pt[1], pt[0]]) #latitude,longitude
    map.add_child(marker) 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00ea4ec5af4e50afb3e649a792137596 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00ea4ec5af4e50afb3e649a792137596&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00ea4ec5af4e50afb3e649a792137596 = L.map(
#                 &quot;map_00ea4ec5af4e50afb3e649a792137596&quot;,
#                 {
#                     center: [36.145059, -86.81236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91fd46e4fa60b2d5b7e78c28c5a19dfd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00ea4ec5af4e50afb3e649a792137596);
#
#
#             var marker_23b458e45ba275919e3c39a64f385c46 = L.marker(
#                 [36.145059, -86.81236],
#                 {}
#             ).addTo(map_00ea4ec5af4e50afb3e649a792137596);
#
#
#             var marker_f32ab57b61f913c9b469000fe840edbd = L.marker(
#                 [36.194334, -86.618303],
#                 {}
#             ).addTo(map_00ea4ec5af4e50afb3e649a792137596);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# change to latitude, longitude order
itin = [(pt[1],pt[0]) for i in points] #latitude longitude
# create graph
G = ox.graph_from_point(itin[0],network_type='walk')
# create the path
path = []
for first, second in zip(itin, itin[1:]):
    one = ox.get_nearest_node(G, first)
    two= ox.get_nearest_node(G, second)
    path.append(nx.shortest_path(G,one,two))
print(path)
[[1261505524], [1261505524, 1261505525, 456520278], [456520278, 1261505525, 4237637413, 5549684249], [5549684249, 4237637412], [4237637412, 4237637410], [4237637410, 460438855], [460438855, 456520295], [456520295, 1261505504]]
# plot
fig, ax = ox.plot_graph_routes(G, path,edge_color='k', bgcolor='w')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 8
#       6 path = []
#       7 for first, second in zip(itin, itin[1:]):
# ----> 8     one = ox.get_nearest_node(G, first)
#       9     two= ox.get_nearest_node(G, second)
#      10     path.append(nx.shortest_path(G,one,two))
#
# AttributeError: module 'osmnx' has no attribute 'get_nearest_node'

# %%
x, y
# Out:
# (array('d', [-86.75560406332076]), array('d', [36.142829720976906]))

# %%
# add an edge attribute for time in minutes required to traverse each edge
meters_per_minute = travel_speed * 1000 / 60 #km per hour to m per minute
for u, v, k, data in G.edges(data=True, keys=True):
    data['time'] = data['length'] / meters_per_minute

# %%
# get one color for each isochrone
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap='plasma', start=0, return_hex=True)

# %%
test = ox.geometries.geometries_from_point([36.138703, -86.801373], tags = {'building': True}, dist = 800)

# %%
test.head(2)
# Out:
#                        addr:state building  ele gnis:county_name gnis:feature_id                      gnis:import_uuid gnis:reviewed                                 name         source                    geometry amenity nodes addr:housename addr:housenumber addr:postcode addr:street image sport building:levels addr:city operator phone website wheelchair wikidata residential brand brand:wikidata internet_access parking surface tourism access  fee supervised layer roof:levels opening_hours wikipedia man_made tower:type social_facility social_facility:for diet:vegetarian brand:wikipedia office shop addr:country air_conditioning  fax internet_access:fee smoking stars roof:shape leisure cuisine drive_through takeaway short_name bench  bin shelter_type note studio brand:en brand:zh name:en name:zh ways club type operator:type
# element_type osmid
# node         368157091         TN      yes  164         Davidson         1954475  57871b70-0100-4405-bb30-88b2e001a944            no  Wilkerson Hearing and Speech Center  USGS Geonames  POINT (-86.79722 36.14422)     NaN   NaN            NaN              NaN           NaN         NaN   NaN   NaN             NaN       NaN      NaN   NaN     NaN        NaN      NaN         NaN   NaN            NaN             NaN     NaN     NaN     NaN    NaN  NaN        NaN   NaN         NaN           NaN       NaN      NaN        NaN             NaN                 NaN             NaN             NaN    NaN  NaN          NaN              NaN  NaN                 NaN     NaN   NaN        NaN     NaN     NaN           NaN      NaN        NaN   NaN  NaN          NaN  NaN    NaN      NaN      NaN     NaN     NaN  NaN  NaN  NaN           NaN
#              368157131         TN      yes  160         Davidson         2453540  57871b70-0100-4405-bb30-88b2e001a944            no                         Wesley Place  USGS Geonames  POINT (-86.79870 36.14580)     NaN   NaN            NaN              NaN           NaN         NaN   NaN   NaN             NaN       NaN      NaN   NaN     NaN        NaN      NaN         NaN   NaN            NaN             NaN     NaN     NaN     NaN    NaN  NaN        NaN   NaN         NaN           NaN       NaN      NaN        NaN             NaN                 NaN             NaN             NaN    NaN  NaN          NaN              NaN  NaN                 NaN     NaN   NaN        NaN     NaN     NaN           NaN      NaN        NaN   NaN  NaN          NaN  NaN    NaN      NaN      NaN     NaN     NaN  NaN  NaN  NaN           NaN

# %%
test = test[['name', 'geometry']]

# %%
test = test.reset_index(drop = True).dropna()

# %%
test.head()
# Out:
#                                   name                    geometry
# 0  Wilkerson Hearing and Speech Center  POINT (-86.79722 36.14422)
# 1                         Wesley Place  POINT (-86.79870 36.14580)
# 2                   Learned Laboratory  POINT (-86.80088 36.14446)
# 3                          Ingram Hall  POINT (-86.80560 36.13873)
# 4      Vanderbilt-Ingram Cancer Center  POINT (-86.80274 36.14013)

# %%
coord_list = [(x,y) for x,y in zip(test['geometry'].centroid.x , test['geometry'].centroid.y)]
# Out:
# C:\Users\jmccall\AppData\Local\Temp\ipykernel_11404\1714859182.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   coord_list = [(x,y) for x,y in zip(test['geometry'].centroid.x , test['geometry'].centroid.y)]
# C:\Users\jmccall\AppData\Local\Temp\ipykernel_11404\1714859182.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   coord_list = [(x,y) for x,y in zip(test['geometry'].centroid.x , test['geometry'].centroid.y)]

# %%
thing = [(36.138703, -86.801373)]

# %%
map = folium.Map((coord_list[0][1],coord_list[0][0]), zoom_start=13)
for pt in coord_list:
    marker = folium.Marker([pt[1], pt[0]]) #latitude,longitude
    map.add_child(marker) 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a679aec67d8e1f31f975f245502ed2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a679aec67d8e1f31f975f245502ed2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a679aec67d8e1f31f975f245502ed2e = L.map(
#                 &quot;map_9a679aec67d8e1f31f975f245502ed2e&quot;,
#                 {
#                     center: [36.1442241, -86.7972213],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_584730c5dc2956c19b1495f402e248a6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_586be234f2bb3ff9b45503de558ecf00 = L.marker(
#                 [36.1442241, -86.7972213],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_32a4c039d52760d7eb891179d136817c = L.marker(
#                 [36.1458, -86.7987],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_977909a352976b5ac9976365a9f5c35f = L.marker(
#                 [36.1444554, -86.8008772],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_cebe5f2894e159d4906ff040ef564f1e = L.marker(
#                 [36.1387276, -86.8056048],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_4de7e35b6e294f300cee2a248da61eff = L.marker(
#                 [36.1401329, -86.8027387],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_7be4b8639ffa6be142b498e71379859c = L.marker(
#                 [36.1357018, -86.7943044],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_d467b521b8259424f9cd5d9e66c586ef = L.marker(
#                 [36.13441, -86.7938686],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_e2e24ec406a2ee6447515079aabbe184 = L.marker(
#                 [36.14478381080773, -86.80311783320273],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_15f48d9e77a0b838e3bbf47a09e06ec8 = L.marker(
#                 [36.14582405370382, -86.8025702123271],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_3df8fbfacdc8eab49f7289d9aa7a0328 = L.marker(
#                 [36.14533601310242, -86.80207894207268],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_c05ed53df2d09aa006d3d7606fb3ba3c = L.marker(
#                 [36.13912797506833, -86.7990902473813],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_8d93d7e8b080a1e5dd25a94c9bbae551 = L.marker(
#                 [36.13957939374668, -86.79901281785273],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_26f417bbe6f6c6606a17b753b9ff91c5 = L.marker(
#                 [36.13998643540145, -86.7990067333809],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_df1a869bbc7c520add5494a1c3b9a820 = L.marker(
#                 [36.13942076599878, -86.80015259765366],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_68263c817d7deaff899ae647ff83d57f = L.marker(
#                 [36.13860142758812, -86.80621654185892],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_8e3916d50f8b7b105ef2adeff00b7345 = L.marker(
#                 [36.13864976159533, -86.80558004527704],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_31db014542adda9d35d8a7be0517008a = L.marker(
#                 [36.143751700769464, -86.80321891165326],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_12b122401d6e9467542b35c5f111f056 = L.marker(
#                 [36.14522158557893, -86.80361637341541],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_b894fe026a4e6a20ada11a72afdeb345 = L.marker(
#                 [36.13646546464186, -86.79914255785097],
#                 {}
#             ).addTo(map_9a679aec67d8e1f31f975f245502ed2e);
#
#
#             var marker_b6791f3b22e8fbd77db406cfa71ca3e0 = L.marker

# %%
test['name'].unique()
# Out:
# array(['Wilkerson Hearing and Speech Center', 'Wesley Place',
#        'Learned Laboratory', 'Ingram Hall',
#        'Vanderbilt-Ingram Cancer Center', 'Barbara massey hall',
#        'Bear house', 'Featheringill / Jacobs Hall', 'Buttrick Hall',
#        'Nuclear Magnetic Resonance Facility',
#        'Village at Vanderbilt - South Tower',
#        'Village at Vanderbilt - North Tower', 'Wyatt Center',
#        'Vanderbilt - Village Commercial', 'Blair School of Music',
#        'Martha River Ingram Center for the Performing Arts',
#        'McTyeire Hall', 'Bryan Building',
#        'Moxy Nashville Vanderbilt Area', 'West House', 'North House',
#        'South Garage', "Children's Hospital Outpatient Clinics",
#        "Children's Hospital at Vanderbilt", 'Vanderbilt Eye Institute',
#        'Hill Center', 'Commons Center', 'Central Parking Garage',
#        'Medical Center East North Tower',
#        'Medical Center East South Tower', 'Dayani Center',
#        'Mayborn Building', 'Payne Building', 'East Garage',
#        'Medical Arts', 'Langford Auditorium',
#        'Robinson Research Building', 'Preston Cancer Research Building',
#        'Mapco', 'East House', 'Gillette House', 'Memorial House',
#        'Olin Hall', 'Science and Engineering Building',
#        'Thomas W. Phillips Memorial', 'Cohen Memorial Hall',
#        'VA Medical Center Garage', 'Eskind Biomedical Library',
#        'Twenty Fifth Avenue Staff Parking Garage', 'Baskin Law Center',
#        'Belmont Bell Tower', 'Hitch Building', 'Hail Hall',
#        'Pembroke Hall', 'Massey Performing Arts Center',
#        'Wilson Music Building', 'Belmont Mansion', 'Fidelity Hall',
#        'Jack C. Massey College of Business', 'Freeman Hall', 'Heron Hall',
#        'Gabhart Student Center', 'Curb Parking Garage',
#        'R. Milton and Denice Johnson Center', 'Gordon E. Inman Center',
#        'McWhorter Hall', 'Janet Ayers Academic Center', 'Patton Hall',
#        'Potter Hall', 'Lila D. Bunch Library', 'Belmont Store',
#        'Foutch Alumni House', 'Helen and Ed Kennedy Hall', 'Maddox Hall',
#        'Wright Hall', 'Beaman Student Life Center/Curb Event Center',
#        'Morningside of Belmont', 'Pancake Pantry',
#        'The Grilled Cheeserie', 'United States Post Office',
#        'Belcourt Theatre', 'Greenery Co',
#        'Cornerstone Financial Credit Union', 'Pangaea',
#        'Rebecca James Clothing', 'Peacock Jewelers', 'The Village Tavern',
#        'Kensington Garage', 'Marriott', 'Morgan House', 'Lewis House',
#        'West Garage', 'Chaffin F', 'Chaffin E', 'Chaffin C', 'Chaffin B',
#        'Chaffin D', 'Chaffin A', 'Mayfield C', 'Mayfield D', 'Mayfield E',
#        'Mayfield A', 'Mayfield B',
#        'Brownlee O Currey Junior Tennis Center',
#        'Jean & Alexander Heard Library', 'Godchaux Nursing Annex',
#        'Frist Hall', 'Stevenson Center for Mathematics',
#        'Tibbot Art Center', 'University School of Nashville', 'PM',
#        "Chago's Cantina", 'blvd Nashville', 'Proper Bagel', 'Local Honey',
#        'Bongo Java', 'Circle K', 'Exxon', 'Cosmic Connections',
#        'Portland Court Apartments',
#        'Biological Sciences Building/Medical Research Building III',
#        'Werthan Building', 'Zerfoss Health Center',
#        'Keck Free Electron Laser Center',
#        'Office of the University Chaplain and Religious Life',
#        'University Club of Nashville', 'Bishop Joseph Johnson Center',
#        'Vaughn Home', 'Stevenson Center Complex', 'Light Hall',
#        'VA Medical Center', 'Home Economics Building',
#        'Peabody Maintenance', 'Curb Center/John Seigenthaler Center',
#        "Dean's Residence", 'Hank Ingram House', 'Stambaugh House',
#        'Murray House', 'Crawford House', 'Sutherland House',
#        'Peabody Administation Building', 'Peabody Library',
#        'Kennedy Center', 'Jesup Psychology Building', 'Hobbs Laboratory',
#        'Village Townhomes', 'English Language Center',
#        'Wesley Place Retail', 'Scales House', 'Vaughn House',
#        'Branscomb Quad Market', 'Student Life Center',
#        'Ben Schulman Center for Jewish Life', 'Memorial Gymnasium',
#        'McGugin Center', 'Vanderbilt Soccer/Lacross Complex',
#        'Vanderbilt Recreation and Wellness Center',
#        'Pi Kappa Alpha House', 'Zeta Beta Tau House',
#        'Multicultural Community Space', 'Baptist Collegiate Ministries',
#        'Alpha Delta Pi House', 'Alpha Chi Omega House', 'Chi Omega House',
#        'Sigma Chi House', 'Sigma Alpha Epsilon House', "Wendy's",
#        'Parmer Field House', 'Community Partnership House',
#        'Molecular Biology', 'Pizza Perfect', "Kay Bob's Grill & Ale",
#        "Sportsman's Grille", 'SunTrust', 'Fifth Third Bank',
#        'Vanderbilt Stallworth Rehabilitation Hospital',
#        'Vanderbilt Psychiatric Hospital', 'Power House',
#        'Vanderbilt University Chancellor Emeritus', 'RCA Label Group',
#        "Aladdin's Hookah Lounge and Bar", 'Cabana',
#        'Scarritt-Bennett Center', 'Whiteman Chapel',
#        'Lincoln-Harding House', 'Young Life', 'Dismas House', 'Foxden',
#        'Osa Coffee Roasters', 'Leu Center for the Visual Arts',
#        'Fannie Mae Dees Picnic Shelter', 'Ruby',
#        'Vanderbilt Home Care Services',
#        'Vanderbilt University : ISIS & ISDE', 'BubbleUp Digital Media',
#        'MV2 Entertainment', 'House of David', 'The Moose Nashville',
#        'Big Machine Label Group', 'Mike Dodd CPA', 'Singing Success',
#        'Liz Rose Music', 'Note 16 Apartments', "McDougal's Chicken",
#        'Belcourt Taps', 'Sushi 88', 'Meet Noodles',
#        "Nicoletto's Italian Kitchen", 'Shokku Ramen', '24th Annex',
#        'VU ROTC', 'VU Real Estate', '18th Ave. Childcare',
#        'Medical Child Care', 'Subway', 'Chatime', 'Childcare',
#        'Stapleton House', '2402 Vanderbilt Place', 'Kappa Sigma House',
#        '2525 West End', 'Stallworth Child Care',
#        'E. Bronson Ingram Studio Art Center', 'Veterans Administration',
#        'Medical Center North', 'Lupton House', 'The Vanderbilt Clinic',
#        'Vanderbilt Hospital'], dtype=object)
